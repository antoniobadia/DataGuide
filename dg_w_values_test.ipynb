# %%
from DataGuidePathClass import DataGuidePath # Importing needed classes
# dg/DG = dataguide

# %%
# Docs to be used for easier test to follow
doc1 = { "sport": "soccer", "difficulty_lvl": 3, "num_balls": 1 } # original base doc
doc2 = { "sport": "dodgeball", "difficulty_lvl": 1, "num_balls": 6 } # original base doc
doc3 = { "sport": "swimming", "difficulty_lvl": 8, "involves_water": "no" } # additional key and value
doc4 = { "sport": "swimming", "difficulty_lvl": 8, "involves_water": "yes" } # additional key and value
doc5 = { "sport": "tennis", "difficulty_lvl": 5, "num_balls": "three" } # num_balls is str type instead of int
doc6 = { "sport": "soccer", "difficulty_lvl": 3, "num_balls": 1, "field_type": "grass" } # additional key and value
doc7 = { "f_name": "John", "l_name": "Smith", "age": 25} # unrelated doc
doc8 = { "sport": "dodgeball", "num_balls": 6 , "difficulty_lvl": 3} # path in different order from base doc
doc9 = { "f_name": "John", "l_name": "Smith", "age": 25, "sport": "soccer"} # different schema with 1 related path
doc10 = { "sport": "basketball", "difficulty_lvl": 6, "num_balls": 1 }
doc11 = { "sport": "soccer", "difficulty_lvl": 3, "num_balls": [1, 2, 3] } # original base doc
doc12 = { "sport": "dodgeball", "difficulty_lvl": 1, "num_balls": 6 } # original base doc
doc13 = { "sport": "baseball", "difficulty_lvl": 4, "num_balls": 5 }
doc14 = { "sport": "volleyball", "difficulty_lvl": 2, "num_balls": 1 }
doc15 = { "num_balls": 1, "sport": "golf", "difficulty_lvl": 7 } #(Different order)
doc16 = { "sport": "hockey", "num_balls": 1, "difficulty_lvl": 9 }#(Different order)
doc17 = { "sport": "badminton", "difficulty_lvl": 2, "num_balls": 1 }
doc18 = { "sport": "running", "difficulty_lvl": 3, "num_balls": 0 }
doc19 = { "sport": "skiing", "difficulty_lvl": 7, "involves_water": "no" }
doc20 = { "sport": "water polo", "difficulty_lvl": 9, "involves_water": "yes" }
doc21 = { "sport": "tennis", "difficulty_lvl": 5, "num_balls": 4 }
doc22 = { "sport": "soccer", "difficulty_lvl": 3, "num_balls": "one" } #(Value type change)
doc23 = { "sport": "boxing", "difficulty_lvl": 8, "equipment": ["gloves", "mouthguard"], "event_date": "2024-12-31" } #(Different order) (Also a date type)
doc24 = { "sport": "baseball", "difficulty_lvl": 4, "num_balls": [1, 2, 3, 4] } #(Value type change to array)
doc25 = { "sport": "fencing", "difficulty_lvl": 6, "num_balls": 0 }
doc26 = { "sport": "archery", "difficulty_lvl": 5, "num_balls": 0 }
doc27 = { "sport": "rock climbing", "difficulty_lvl": 8, "num_balls": None } #(Null value)
doc28 = { "sport": "dodgeball", "difficulty_lvl": 1, "num_balls": 6.5 } #(Float value, new type)
doc29 = { "sport": "cycling", "difficulty_lvl": 4, "involves_water": "no" }
doc30 = { "sport": "diving", "difficulty_lvl": 7, "involves_water": "yes" }
doc31 = { "sport": "handball", "difficulty_lvl": 3, "num_balls": 1 }
doc32 = { "sport": "football", "difficulty_lvl": 6, "num_balls": 1, "is_team_sport": True } #(New key: is_team_sport)
doc33 = { "sport": "boxing", "difficulty_lvl": 8, "equipment": ["gloves", "mouthguard"] }# (New key: equipment)
doc34 = { "sport": "gymnastics", "difficulty_lvl": 10, "judged": True } #(New key: judged)
doc35 = { "sport": "karate", "difficulty_lvl": 7, "indoor_sport": False } #(New key: indoor_sport)
doc36 = { "sport": "surfing", "difficulty_lvl": 9, "involves_water": "yes", "board_type": "longboard" } #(New key: board_type)
doc37 = { "sport": "curling", "difficulty_lvl": 1, "num_balls": 8, "requires_ice": True, "event_date": "2025-01-15" } #(New key: requires_ice)
doc38 = { "sport": "lacrosse", "difficulty_lvl": 7, "num_players": 10, "num_balls": 1 } #(New key: num_players)
doc39 = { "sport": "badminton", "difficulty_lvl": 2, "num_balls": 1, "requires_net": True } #(New key: requires_net)
doc40 = { "sport": "darts", "difficulty_lvl": 3, "num_balls": 3, "max_score": 501 } #(New key: max_score)

# %%
#Loading all 40 docs above into a DG for testing of new insert function 
# which tracks unique values for paths
# since doc1–doc40 are already defined
all_docs = [globals()[f"doc{i}"] for i in range(1, 41)]
dg = DataGuidePath()
dg.insert_document_with_values(all_docs)

# %%
dg.print_guide_values()
# Seems to be working correctly
# Print each unique path and the counters for the top 5 unique values if they exist
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 40, 'arr': 0}
# root.sport: {'int': 0, 'str': 39, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
#  Distinct values (top 5 of 27): [('soccer', 5), ('dodgeball', 4), ('swimming', 2), ('tennis', 2), ('baseball', 2)]
# root.difficulty_lvl: {'int': 38, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
#  Distinct values (top 5 of 10): [(3, 8), (8, 5), (7, 5), (1, 4), (5, 3)]
# root.num_balls: {'int': 21, 'str': 2, 'float': 1, 'date': 0, 'obj': 0, 'arr': 2, 'NoneType': 1}
#  Distinct values (top 5 of 13): [(1, 11), (6, 3), (0, 3), ('three', 1), ('[1, 2, 3]', 1)]
# root.num_balls.*: {'int': 7, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
#  Distinct values (top 5 of 4): [(1, 2), (2, 2), (3, 2), (4, 1)]
# root.involves_water: {'int': 0, 'str': 7, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
#  Distinct values (top 5 of 2): [('yes', 4), ('no', 3)]
# root.field_type: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# ...

# %%
# Now testing the runtime for a much larger dataset
# 1.58GB of data of 1000 patients
import os
import json

# Path to folder
folder = "patient_data\sample-bulk-fhir-datasets-1000-patients\sample-bulk-fhir-datasets-1000-patients"

# Create the DataGuidePath instance
patient_data_dg = DataGuidePath()

# Loop through all .ndjson files in the folder
for filename in sorted(os.listdir(folder)):
    if not filename.endswith(".ndjson"):
        continue
    if filename == "log.ndjson":
        continue  # skip the log file

    file_path = os.path.join(folder, filename)
    print(f"Loading {file_path}...")

    # Each NDJSON file contains one JSON object per line
    with open(file_path, "r", encoding="utf-8") as f:
        for line in f:
            line = line.strip()
            if not line:
                continue
            try:
                doc = json.loads(line)
                patient_data_dg.insert_document_with_values(doc)
            except json.JSONDecodeError as e:
                print(f"Skipping invalid JSON line in {filename}: {e}")

print("\n All NDJSON files loaded into DataGuidePath (excluding log.ndjson).")

# Runtime 2m 20.5s, roughly 1min more than without these values
# Out:
# Loading patient_data\sample-bulk-fhir-datasets-1000-patients\sample-bulk-fhir-datasets-1000-patients\AllergyIntolerance.000.ndjson...
# Loading patient_data\sample-bulk-fhir-datasets-1000-patients\sample-bulk-fhir-datasets-1000-patients\Condition.000.ndjson...
# Loading patient_data\sample-bulk-fhir-datasets-1000-patients\sample-bulk-fhir-datasets-1000-patients\Device.000.ndjson...
# Loading patient_data\sample-bulk-fhir-datasets-1000-patients\sample-bulk-fhir-datasets-1000-patients\DiagnosticReport.000.ndjson...
# Loading patient_data\sample-bulk-fhir-datasets-1000-patients\sample-bulk-fhir-datasets-1000-patients\DiagnosticReport.001.ndjson...
# Loading patient_data\sample-bulk-fhir-datasets-1000-patients\sample-bulk-fhir-datasets-1000-patients\DiagnosticReport.002.ndjson...
# Loading patient_data\sample-bulk-fhir-datasets-1000-patients\sample-bulk-fhir-datasets-1000-patients\DiagnosticReport.003.ndjson...
# ...

# %%
# Printing the dg of patient data
patient_data_dg.print_guide_values()
# Original Counters remain the same, and distinct value counters are working well.
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1330501, 'arr': 0}
#   root.resourceType: {'int': 0, 'str': 1330501, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
#   root.id: {'int': 0, 'str': 1330501, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
#   root.meta: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1220692, 'arr': 0}
#     root.meta.profile: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 1220692}
#       root.meta.profile.*: {'int': 0, 'str': 1253255, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
#   root.clinicalStatus: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 46375, 'arr': 0}
#     root.clinicalStatus.coding: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 46375}
#       root.clinicalStatus.coding.*: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 46375, 'arr': 0}
#         root.clinicalStatus.coding.*.system: {'int': 0, 'str': 46375, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# ...

# %%
# Comparing to original dataguide/ insert method with no unique value counters

import os
import json

# Path to folder
folder = "patient_data\sample-bulk-fhir-datasets-1000-patients\sample-bulk-fhir-datasets-1000-patients"

# Create the DataGuidePath instance
patient_data_dg = DataGuidePath()

# Loop through all .ndjson files in the folder
for filename in sorted(os.listdir(folder)):
    if not filename.endswith(".ndjson"):
        continue
    if filename == "log.ndjson":
        continue  # skip the log file

    file_path = os.path.join(folder, filename)
    print(f"Loading {file_path}...")

    # Each NDJSON file contains one JSON object per line
    with open(file_path, "r", encoding="utf-8") as f:
        for line in f:
            line = line.strip()
            if not line:
                continue
            try:
                doc = json.loads(line)
                patient_data_dg.insert_document(doc)
            except json.JSONDecodeError as e:
                print(f"Skipping invalid JSON line in {filename}: {e}")

print("\n All NDJSON files loaded into DataGuidePath (excluding log.ndjson).")
#RUNTIME is about 1m 30s
# Out:
# Loading patient_data\sample-bulk-fhir-datasets-1000-patients\sample-bulk-fhir-datasets-1000-patients\AllergyIntolerance.000.ndjson...
# Loading patient_data\sample-bulk-fhir-datasets-1000-patients\sample-bulk-fhir-datasets-1000-patients\Condition.000.ndjson...
# Loading patient_data\sample-bulk-fhir-datasets-1000-patients\sample-bulk-fhir-datasets-1000-patients\Device.000.ndjson...
# Loading patient_data\sample-bulk-fhir-datasets-1000-patients\sample-bulk-fhir-datasets-1000-patients\DiagnosticReport.000.ndjson...
# Loading patient_data\sample-bulk-fhir-datasets-1000-patients\sample-bulk-fhir-datasets-1000-patients\DiagnosticReport.001.ndjson...
# Loading patient_data\sample-bulk-fhir-datasets-1000-patients\sample-bulk-fhir-datasets-1000-patients\DiagnosticReport.002.ndjson...
# Loading patient_data\sample-bulk-fhir-datasets-1000-patients\sample-bulk-fhir-datasets-1000-patients\DiagnosticReport.003.ndjson...
# ...

# %%
patient_data_dg.print_guide()
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1330501, 'arr': 0}
# root.resourceType: {'int': 0, 'str': 1330501, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.id: {'int': 0, 'str': 1330501, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.meta: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1220692, 'arr': 0}
# root.meta.profile: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 1220692}
# root.meta.profile.*: {'int': 0, 'str': 1253255, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.clinicalStatus: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 46375, 'arr': 0}
# root.clinicalStatus.coding: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 46375}
# root.clinicalStatus.coding.*: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 46375, 'arr': 0}
# root.clinicalStatus.coding.*.system: {'int': 0, 'str': 46375, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# ...

# %%
# Testing on Yelp dataset which is an even larger dataset 
# 8.65GB of data

import os
import json

# Path to folder
folder = "yelp_data\yelp_dataset"

# Create the DataGuidePath instance
yelp_data_dg = DataGuidePath()

# Loop through all .ndjson files in the folder
for filename in sorted(os.listdir(folder)):
    if not filename.endswith(".json"):
        continue

    file_path = os.path.join(folder, filename)
    print(f"Loading {file_path}...")

    # Each NDJSON file contains one JSON object per line
    with open(file_path, "r", encoding="utf-8") as f:
        for line in f:
            line = line.strip()
            if not line:
                continue
            try:
                doc = json.loads(line)
                yelp_data_dg.insert_document_with_values(doc)
            except json.JSONDecodeError as e:
                print(f"Skipping invalid JSON line in {filename}: {e}")
              

print("\n All files loaded into DataGuidePath.")
#Runtime 4m 33.6s
# Out:
# Loading yelp_data\yelp_dataset\yelp_academic_dataset_business.json...
# Loading yelp_data\yelp_dataset\yelp_academic_dataset_checkin.json...
# Loading yelp_data\yelp_dataset\yelp_academic_dataset_review.json...
# Loading yelp_data\yelp_dataset\yelp_academic_dataset_tip.json...
# Loading yelp_data\yelp_dataset\yelp_academic_dataset_user.json...
#
#  All files loaded into DataGuidePath.

# %%
yelp_data_dg.print_guide_values()
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 10169368, 'arr': 0}
#   root.business_id: {'int': 0, 'str': 8181471, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
#   root.name: {'int': 0, 'str': 2138243, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
#   root.address: {'int': 0, 'str': 150230, 'float': 0, 'date': 116, 'obj': 0, 'arr': 0}
#   root.city: {'int': 0, 'str': 150346, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
#   root.state: {'int': 0, 'str': 150346, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
#   root.postal_code: {'int': 0, 'str': 150346, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
#   root.latitude: {'int': 0, 'str': 0, 'float': 150346, 'date': 0, 'obj': 0, 'arr': 0}
#   root.longitude: {'int': 0, 'str': 0, 'float': 150346, 'date': 0, 'obj': 0, 'arr': 0}
#   root.stars: {'int': 0, 'str': 0, 'float': 7140626, 'date': 0, 'obj': 0, 'arr': 0}
#   root.review_count: {'int': 2138243, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# ...

# %%
# For comparing to original insert/ schema

import os

import json

# Path to folder
folder = "yelp_data\yelp_dataset"

# Create the DataGuidePath instance
yelp_data_dg_orig_schema = DataGuidePath()

# Loop through all .ndjson files in the folder
for filename in sorted(os.listdir(folder)):
    if not filename.endswith(".json"):
        continue

    file_path = os.path.join(folder, filename)
    print(f"Loading {file_path}...")

    # Each NDJSON file contains one JSON object per line
    with open(file_path, "r", encoding="utf-8") as f:
        for line in f:
            line = line.strip()
            if not line:
                continue
            try:
                doc = json.loads(line)
                yelp_data_dg_orig_schema.insert_document(doc)
            except json.JSONDecodeError as e:
                print(f"Skipping invalid JSON line in {filename}: {e}")
              

print("\n All files loaded into DataGuidePath.")

# Runtime is 3m 32.5s
# Out:
# Loading yelp_data\yelp_dataset\yelp_academic_dataset_business.json...
# Loading yelp_data\yelp_dataset\yelp_academic_dataset_checkin.json...
# Loading yelp_data\yelp_dataset\yelp_academic_dataset_review.json...
# Loading yelp_data\yelp_dataset\yelp_academic_dataset_tip.json...
# Loading yelp_data\yelp_dataset\yelp_academic_dataset_user.json...
#
#  All files loaded into DataGuidePath.

# %%
# Testing code on large github dataset
# 2.59GB of data

import os
import json

folder = "gh_archive_2015_01_01_to_05"

gh_lrg_dg = DataGuidePath()

# Loop through all .json files in the folder
for filename in sorted(os.listdir(folder)):
    if not filename.endswith(".json"):
        continue

    file_path = os.path.join(folder, filename)
    print(f"Loading {file_path}...")

    # Each JSON file contains one JSON object per line
    with open(file_path, "r", encoding="utf-8") as f:
        for line in f:
            line = line.strip()
            if not line:
                continue
            try:
                doc = json.loads(line)
                gh_lrg_dg.insert_document_with_values(doc)
            except json.JSONDecodeError as e:
                print(f"Skipping invalid JSON line in {filename}: {e}")
              

print("\n All files loaded into DataGuidePath.")
# Runtime 2m 34.9s
# Out:
# Loading gh_archive_2015_01_01_to_05\2015-01-01-10.json...
# Loading gh_archive_2015_01_01_to_05\2015-01-01-11.json...
# Loading gh_archive_2015_01_01_to_05\2015-01-01-12.json...
# Loading gh_archive_2015_01_01_to_05\2015-01-01-13.json...
# Loading gh_archive_2015_01_01_to_05\2015-01-01-14.json...
# Loading gh_archive_2015_01_01_to_05\2015-01-01-15.json...
# Loading gh_archive_2015_01_01_to_05\2015-01-01-16.json...
# Loading gh_archive_2015_01_01_to_05\2015-01-01-17.json...
# Loading gh_archive_2015_01_01_to_05\2015-01-01-18.json...
# Loading gh_archive_2015_01_01_to_05\2015-01-01-19.json...
# Loading gh_archive_2015_01_01_to_05\2015-01-01-20.json...
# Loading gh_archive_2015_01_01_to_05\2015-01-01-21.json...
# Loading gh_archive_2015_01_01_to_05\2015-01-01-22.json...
# Loading gh_archive_2015_01_01_to_05\2015-01-01-23.json...
# Loading gh_archive_2015_01_01_to_05\2015-01-02-10.json...
# Loading gh_archive_2015_01_01_to_05\2015-01-02-11.json...
# ...

# %%
gh_lrg_dg.print_guide_values()
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1087835, 'arr': 0}
#   root.id: {'int': 0, 'str': 1087835, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
#   root.type: {'int': 0, 'str': 1087835, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
#   root.actor: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1087835, 'arr': 0}
#     root.actor.id: {'int': 1087835, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
#     root.actor.login: {'int': 0, 'str': 1087834, 'float': 0, 'date': 1, 'obj': 0, 'arr': 0}
#     root.actor.gravatar_id: {'int': 0, 'str': 1087835, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
#     root.actor.url: {'int': 0, 'str': 1087835, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
#     root.actor.avatar_url: {'int': 0, 'str': 1087835, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
#   root.repo: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1087835, 'arr': 0}
#     root.repo.id: {'int': 1087835, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# ...

# %%
#Comparing to original insert without distinct value counters

import os
import json

folder = "gh_archive_2015_01_01_to_05"

gh_lrg_dg_original = DataGuidePath()

# Loop through all .json files in the folder
for filename in sorted(os.listdir(folder)):
    if not filename.endswith(".json"):
        continue

    file_path = os.path.join(folder, filename)
    print(f"Loading {file_path}...")

    # Each JSON file contains one JSON object per line
    with open(file_path, "r", encoding="utf-8") as f:
        for line in f:
            line = line.strip()
            if not line:
                continue
            try:
                doc = json.loads(line)
                gh_lrg_dg_original.insert_document(doc)
            except json.JSONDecodeError as e:
                print(f"Skipping invalid JSON line in {filename}: {e}")
              

print("\n All files loaded into DataGuidePath.")

#Runtime 1m 59.6s
# Out:
# Loading gh_archive_2015_01_01_to_05\2015-01-01-10.json...
# Loading gh_archive_2015_01_01_to_05\2015-01-01-11.json...
# Loading gh_archive_2015_01_01_to_05\2015-01-01-12.json...
# Loading gh_archive_2015_01_01_to_05\2015-01-01-13.json...
# Loading gh_archive_2015_01_01_to_05\2015-01-01-14.json...
# Loading gh_archive_2015_01_01_to_05\2015-01-01-15.json...
# Loading gh_archive_2015_01_01_to_05\2015-01-01-16.json...
# Loading gh_archive_2015_01_01_to_05\2015-01-01-17.json...
# Loading gh_archive_2015_01_01_to_05\2015-01-01-18.json...
# Loading gh_archive_2015_01_01_to_05\2015-01-01-19.json...
# Loading gh_archive_2015_01_01_to_05\2015-01-01-20.json...
# Loading gh_archive_2015_01_01_to_05\2015-01-01-21.json...
# Loading gh_archive_2015_01_01_to_05\2015-01-01-22.json...
# Loading gh_archive_2015_01_01_to_05\2015-01-01-23.json...
# Loading gh_archive_2015_01_01_to_05\2015-01-02-10.json...
# Loading gh_archive_2015_01_01_to_05\2015-01-02-11.json...
# ...

# %%
# Large Amazon review dataset but few paths
# 0.97 GB
import os
import json

# Path to folder
folder = "amazon_fashion_data"

# Create the DataGuidePath instance
am_fashion_dg = DataGuidePath()

for root, _, files in os.walk(folder):
    for fname in files:
        if fname == "log.ndjson":
            continue
        if not fname.endswith((".ndjson", ".jsonl")):
            continue

        file_path = os.path.join(root, fname)
        print(f"Loading {file_path}...")

        with open(file_path, "r", encoding="utf-8") as f:
            for line in f:
                line = line.strip()
                if not line:
                    continue
                try:
                    doc = json.loads(line)
                    am_fashion_dg.insert_document_with_values(doc)
                except json.JSONDecodeError:
                    print(f"⚠️ Skipping invalid JSON in {file_path}")
                    

print("\n All files loaded into DataGuidePath.")

# Runtime 1m 4.3s
# Out:
# Loading amazon_fashion_data\Amazon_Fashion.jsonl\Amazon_Fashion.jsonl...
#
#  All files loaded into DataGuidePath.

# %%
am_fashion_dg.print_guide_values()
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 2500939, 'arr': 0}
#   root.rating: {'int': 0, 'str': 0, 'float': 2500939, 'date': 0, 'obj': 0, 'arr': 0}
#   root.title: {'int': 0, 'str': 2500937, 'float': 0, 'date': 2, 'obj': 0, 'arr': 0}
#   root.text: {'int': 0, 'str': 2500939, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
#   root.images: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 2500939}
#     root.images.*: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 273580, 'arr': 0}
#       root.images.*.small_image_url: {'int': 0, 'str': 273580, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
#       root.images.*.medium_image_url: {'int': 0, 'str': 273580, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
#       root.images.*.large_image_url: {'int': 0, 'str': 273580, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
#       root.images.*.attachment_type: {'int': 0, 'str': 273580, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# ...

# %%
# %load_ext autoreload
# %autoreload 2
from DataGuidePathClass import DataGuidePath
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
#Printing the original DG for reference
yelp_data_dg.print_guide_values()
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 10169368, 'arr': 0}
# root.business_id: {'int': 0, 'str': 8181471, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
#  [high-cardinality: >1000 unique values]
# root.name: {'int': 0, 'str': 2138243, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
#  [high-cardinality: >1000 unique values]
# root.address: {'int': 0, 'str': 150230, 'float': 0, 'date': 116, 'obj': 0, 'arr': 0}
#  [high-cardinality: >1000 unique values]
# root.city: {'int': 0, 'str': 150346, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
#  [high-cardinality: >1000 unique values]
# root.state: {'int': 0, 'str': 150346, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
#  Distinct values (top 5 of 27): [('PA', 34039), ('FL', 26330), ('TN', 12056), ('IN', 11247), ('MO', 10913)]
# root.postal_code: {'int': 0, 'str': 150346, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
#  [high-cardinality: >1000 unique values]
# ...

# %%
# Start by testing if we can print just the data for the path we are interested in grouping
nested_summary_dg = yelp_data_dg.nest_schema_w_values(
    grouping_paths=["average_stars"],
    nest_specs=[],
    aggregations=None,
    max_values=5
)

nested_summary_dg.print_guide_values()
# Output is the path, the number of objects in that path, float': 1987897 is correct
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 0}
#   root.average_stars: {'int': 0, 'str': 0, 'float': 1987897, 'date': 0, 'obj': 0, 'arr': 0}
#     Distinct values (top 5 of 9): [(5.0, 3247934), (4.0, 1484043), (1.0, 1071547), (3.0, 710387), (2.0, 553767)]

# %%
# Testing by adding a nest under name, and the additiona two paths to nest in 'user_stats'
nested_summary_dg = yelp_data_dg.nest_schema_w_values(
    grouping_paths=["average_stars"],
    nest_specs=[("user_stats", ["fans", "compliment_count"])],
    aggregations=None,
    max_values=5
)

nested_summary_dg.print_guide_values()

# Output expected is same as above + two additonal paths with counters for types
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 2, 'arr': 1}
#   root.average_stars: {'int': 0, 'str': 0, 'float': 1987897, 'date': 0, 'obj': 0, 'arr': 0}
#     Distinct values (top 5 of 401): [(5.0, 356368), (1.0, 165899), (3.0, 111842), (4.0, 102764), (3.67, 50379)]
#   root.user_stats: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 1}
#     root.user_stats.*: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
#       root.user_stats.*.compliment_count: {'int': 908915, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
#         Distinct values (top 5 of 7): [(0, 898376), (1, 9821), (2, 617), (3, 82), (4, 14)]
#       root.user_stats.*.fans: {'int': 1987897, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
#         Distinct values (top 5 of 691): [(0, 1577870), (1, 199819), (2, 65897), (3, 32207), (4, 19412)]

# %%
# Testing max calues for functionality
nested_summary_dg = yelp_data_dg.nest_schema_w_values(
    grouping_paths=["average_stars"],
    nest_specs=[("user_stats", ["fans", "compliment_count"])],
    aggregations=None
)

nested_summary_dg.print_guide_values(max_values=5)
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 2, 'arr': 1}
#   root.average_stars: {'int': 0, 'str': 0, 'float': 1987897, 'date': 0, 'obj': 0, 'arr': 0}
#     Distinct values (top 5 of 401): [(5.0, 356368), (1.0, 165899), (3.0, 111842), (4.0, 102764), (3.67, 50379)]
#   root.user_stats: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 1}
#     root.user_stats.*: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
#       root.user_stats.*.compliment_count: {'int': 908915, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
#         Distinct values (top 5 of 7): [(0, 898376), (1, 9821), (2, 617), (3, 82), (4, 14)]
#       root.user_stats.*.fans: {'int': 1987897, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
#         Distinct values (top 5 of 691): [(0, 1577870), (1, 199819), (2, 65897), (3, 32207), (4, 19412)]

# %%
# Need to add distinct values to nested paths

# %%
# Testing two group by
nested_summary_dg = yelp_data_dg.nest_schema_w_values(
    grouping_paths=["average_stars", "fans"],
    nest_specs=[],
    aggregations=None
)

nested_summary_dg.print_guide_values()
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 0}
#   root.average_stars: {'int': 0, 'str': 0, 'float': 1987897, 'date': 0, 'obj': 0, 'arr': 0}
#     Distinct values (top 5 of 401): [(5.0, 356368), (1.0, 165899), (3.0, 111842), (4.0, 102764), (3.67, 50379)]
#   root.fans: {'int': 1987897, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
#     Distinct values (top 5 of 691): [(0, 1577870), (1, 199819), (2, 65897), (3, 32207), (4, 19412)]

# %%
#comparing to original schema function
nested_summary_dg = yelp_data_dg.nest_schema(
    grouping_paths=["average_stars", "fans"],
    nest_specs=[],
    aggregations=None
)

nested_summary_dg.print_guide_values()
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 0}
# root.average_stars: {'int': 0, 'str': 0, 'float': 1987897, 'date': 0, 'obj': 0, 'arr': 0}
# root.fans: {'int': 1987897, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}

# %%
#comparing to original schema function
nested_summary_dg = yelp_data_dg.nest_schema(
    grouping_paths=["average_stars", "fans"],
    nest_specs=[("user_stats", ["fans", "compliment_count"])],
    aggregations=None
)

nested_summary_dg.print_guide_values()
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 2, 'arr': 1}
# root.user_stats: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 1}
# root.user_stats.*: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.user_stats.*.compliment_count: {'int': 908915, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.user_stats.*.fans: {'int': 1987897, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.fans: {'int': 1987897, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.average_stars: {'int': 0, 'str': 0, 'float': 1987897, 'date': 0, 'obj': 0, 'arr': 0}

# %%
# Code being ran in mongoDB along with sample output, full if it doesnt take up alot of space

# db.reviews.aggregate([
#   {
#     $group: {
#       _id: {
#         average_stars: "$average_stars",
#         compliment_profile: "$compliment_profile"
#       },
#       count: { $sum: 1 }
#     }
#   },
#   { $sort: { count: -1 } }
# ])

# Output:

# [
#   { _id: {}, count: 8181471 }, # This means out of 10,169,368 docs, 8,181,471 docs have neither average_stars nor compliment_profile defined
#   { _id: { average_stars: 5, compliment_profile: 0 }, count: 355977 },
#   { _id: { average_stars: 1, compliment_profile: 0 }, count: 165847 },
#   { _id: { average_stars: 3, compliment_profile: 0 }, count: 111649 },
#   { _id: { average_stars: 4, compliment_profile: 0 }, count: 101717 },
#   { _id: { average_stars: 3.67, compliment_profile: 0 }, count: 49782 },
#   { _id: { average_stars: 2, compliment_profile: 0 }, count: 49025 },
#   { _id: { average_stars: 4.5, compliment_profile: 0 }, count: 39569 },
#   { _id: { average_stars: 3.5, compliment_profile: 0 }, count: 34619 },
#   { _id: { average_stars: 2.33, compliment_profile: 0 }, count: 26546 },
#   { _id: { average_stars: 4.33, compliment_profile: 0 }, count: 26309 },
#   { _id: { average_stars: 4.67, compliment_profile: 0 }, count: 21400 },
#   { _id: { average_stars: 4.2, compliment_profile: 0 }, count: 20284 },
#   { _id: { average_stars: 2.5, compliment_profile: 0 }, count: 17396 },
#   { _id: { average_stars: 3.33, compliment_profile: 0 }, count: 16944 },
#   { _id: { average_stars: 4.25, compliment_profile: 0 }, count: 15410 },
#   { _id: { average_stars: 3.75, compliment_profile: 0 }, count: 14226 },
#   { _id: { average_stars: 3.4, compliment_profile: 0 }, count: 14091 },
#   { _id: { average_stars: 4.75, compliment_profile: 0 }, count: 12819 },
#   { _id: { average_stars: 2.67, compliment_profile: 0 }, count: 12711 }
# ]

# To verify our counters are correct

# db.reviews.aggregate([
#   { $match: { average_stars: 5 } },
#   {
#     $group: {
#       _id: "$compliment_profile",
#       count: { $sum: 1 }
#     }
#   },
#   { $sort: { count: -1 } }
# ])

# Output:
# [
#   { _id: 0, count: 355977 },
#   { _id: 1, count: 369 },
#   { _id: 2, count: 19 },
#   { _id: 3, count: 1 },
#   { _id: 4, count: 1 },
#   { _id: 281, count: 1 }
# ] # this adds up to 355977 as shown in query

# To find out how many groups are created I ran the following:

# db.reviews.aggregate([
#   {
#     $group: {
#       _id: {
#         average_stars: "$average_stars",
#         compliment_profile: "$compliment_profile"
#       },
#       count: { $sum: 1 }
#     }
#   },
#   { $group: { _id: null, numGroups: { $sum: 1 } } }
# ])

# Output:
# [ { _id: null, numGroups: 4770 } ]

# This means 4770 groups were created from grouping by 'average_stars' and

# %%
# Running the same query above but in DG, old nest schema for simple comparison

nested_summary_dg = yelp_data_dg.nest_schema(
    grouping_paths=["average_stars", "compliment_profile"],
    nest_specs=[],
    aggregations=None
)

nested_summary_dg.print_guide_values()
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 0}
#   root.average_stars: {'int': 0, 'str': 0, 'float': 1987897, 'date': 0, 'obj': 0, 'arr': 0}
#   root.compliment_profile: {'int': 1987897, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}

# %%
# New nest schema with values, comparing to mongoDB query
nested_summary_dg = yelp_data_dg.nest_schema_w_values(
    grouping_paths=["average_stars", "compliment_profile"],
    nest_specs=[],
    aggregations=None
)

nested_summary_dg.print_guide_values(max_values=401)
# Current output is:

# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 0}
#   root.average_stars: {'int': 0, 'str': 0, 'float': 1987897, 'date': 0, 'obj': 0, 'arr': 0}
#     Distinct values (top 5 of 401): [(5.0, 356368), (1.0, 165899), (3.0, 111842), (4.0, 102764), (3.67, 50379)]
#   root.compliment_profile: {'int': 1987897, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
#     Distinct values (top 5 of 345): [(0, 1926126), (1, 38143), (2, 9544), (3, 4217), (4, 2256)]

# From this we can say there are at least 401*345 = 138,345 posible groups, mongoDB confirmed 4770 groups
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 138345, 'arr': 0}
#   root.average_stars: {'int': 0, 'str': 0, 'float': 1987897, 'date': 0, 'obj': 0, 'arr': 0}
# ...

# %%
# Similar tests to above, checking distinct value outputs
nested_summary_dg = gh_lrg_dg.nest_schema_w_values(
    grouping_paths=["type", "payload.pages.summary"],
    nest_specs=[],       
    aggregations=None    
)
nested_summary_dg.print_guide_values()
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 14, 'arr': 0}
#   root.type: {'int': 0, 'str': 1087835, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
#     Distinct values (top 5 of 14): [('PushEvent', 554612), ('CreateEvent', 116778), ('IssueCommentEvent', 108385), ('WatchEvent', 103723), ('IssuesEvent', 57375)]

# %%
# Similar tests to above, checking distinct value outputs
nested_summary_dg = gh_lrg_dg.nest_schema_w_values(
    grouping_paths=["type"],
    nest_specs=[],       
    aggregations=None    
)
nested_summary_dg.print_guide_values()
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 14, 'arr': 0}
#   root.type: {'int': 0, 'str': 1087835, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
#     Distinct values (top 5 of 14): [('PushEvent', 554612), ('CreateEvent', 116778), ('IssueCommentEvent', 108385), ('WatchEvent', 103723), ('IssuesEvent', 57375)]

# %%
# Similar tests to above, checking distinct value outputs
nested_summary_dg = gh_lrg_dg.nest_schema_w_values(
    grouping_paths=["payload.pages.summary"],
    nest_specs=[],       
    aggregations=None    
)
nested_summary_dg.print_guide_values()
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 0}

# %%
# Testing prior nest_schema function
nested_summary_dg = gh_lrg_dg.nest_schema(
    grouping_paths=["type", "payload.release.prerelease"],
    nest_specs=[],
    aggregations=None
)

nested_summary_dg.print_guide_values()
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 0}
#   root.payload: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 0}
#     root.payload.release: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
#       root.payload.release.prerelease: {'int': 3765, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
#   root.type: {'int': 0, 'str': 1087835, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}

# %%
# Nest Schema allows for a change in max_values displayed, to see more distinct values
nested_summary_dg = gh_lrg_dg.nest_schema_w_values(
    grouping_paths=["type", "payload.release.prerelease"],
    nest_specs=[],
    aggregations=None
)

nested_summary_dg.print_guide_values(max_values=14)
# Uniquely root.type distinct value ReleaseEvent at 3765 matches root.payload.release.prerelease: {'int': 3765, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 28, 'arr': 0}
#   root.payload: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 0}
#     [high-cardinality: >14 unique values]
#     root.payload.release: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
#       [high-cardinality: >14 unique values]
#       root.payload.release.prerelease: {'int': 3765, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
#         Distinct values (top 2 of 2): [(False, 3031), (True, 734)]
#   root.type: {'int': 0, 'str': 1087835, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# ...

# %%
# Checking how many attributes stem from one
gh_lrg_dg.count_subpaths("root.payload.release")
# Out:
# 17

# %%
# Changing number of distinct values shown to 10 in dataguide
gh_lrg_dg.print_guide_values(max_values=10)
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1087835, 'arr': 0}
#   root.id: {'int': 0, 'str': 1087835, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
#     [high-cardinality: >1000 unique values]
#   root.type: {'int': 0, 'str': 1087835, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
#     Distinct values (top 10 of 14): [('PushEvent', 554612), ('CreateEvent', 116778), ('IssueCommentEvent', 108385), ('WatchEvent', 103723), ('IssuesEvent', 57375), ('PullRequestEvent', 49785), ('ForkEvent', 34012), ('DeleteEvent', 19750), ('PullRequestReviewCommentEvent', 16035), ('GollumEvent', 11035)]
#   root.actor: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1087835, 'arr': 0}
#     [high-cardinality: >1000 unique values]
#     root.actor.id: {'int': 1087835, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
#       [high-cardinality: >1000 unique values]
#     root.actor.login: {'int': 0, 'str': 1087834, 'float': 0, 'date': 1, 'obj': 0, 'arr': 0}
# ...

# %%
# Will test several outputs from mongoDB for comparison
# Running tests here and comparing to mongoDB, same data uploaded
nested_summary_dg = gh_lrg_dg.nest_schema_w_values(
    grouping_paths=["type", "payload.release.url"],
    nest_specs=[],
    aggregations=None
)

nested_summary_dg.print_guide_values(max_values=10)
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 14, 'arr': 0}
#   root.payload: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 0}
#     [high-cardinality: >10 unique values]
#     root.payload.release: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
#       [high-cardinality: >10 unique values]
#       root.payload.release.url: {'int': 0, 'str': 3765, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
#         [high-cardinality: >10 unique values]
#   root.type: {'int': 0, 'str': 1087835, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
#     Distinct values (top 10 of 14): [('PushEvent', 554612), ('CreateEvent', 116778), ('IssueCommentEvent', 108385), ('WatchEvent', 103723), ('IssuesEvent', 57375), ('PullRequestEvent', 49785), ('ForkEvent', 34012), ('DeleteEvent', 19750), ('PullRequestReviewCommentEvent', 16035), ('GollumEvent', 11035)]

# %%
# Running tests here and comparing to mongoDB, same data uploaded, distinct values being shown to 14
# Repititive test below to learn schema (Eventually this was used to create helper functions based on observations like 
# show_distinct_to_path_matches, find_cooccurring_paths, and find_exact_sum_relationships)
nested_summary_dg = gh_lrg_dg.nest_schema_w_values(
    grouping_paths=["type", "payload.release.assets_url"],
    nest_specs=[],
    aggregations=None
)

nested_summary_dg.print_guide_values(max_values=14)
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 14, 'arr': 0}
#   root.payload: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 0}
#     [high-cardinality: >14 unique values]
#     root.payload.release: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
#       [high-cardinality: >14 unique values]
#       root.payload.release.assets_url: {'int': 0, 'str': 3765, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
#         [high-cardinality: >14 unique values]
#   root.type: {'int': 0, 'str': 1087835, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
#     Distinct values (top 14 of 14): [('PushEvent', 554612), ('CreateEvent', 116778), ('IssueCommentEvent', 108385), ('WatchEvent', 103723), ('IssuesEvent', 57375), ('PullRequestEvent', 49785), ('ForkEvent', 34012), ('DeleteEvent', 19750), ('PullRequestReviewCommentEvent', 16035), ('GollumEvent', 11035), ('CommitCommentEvent', 7790), ('ReleaseEvent', 3765), ('MemberEvent', 3743), ('PublicEvent', 1047)]

# %%
# Running tests here and comparing to mongoDB, same data uploaded, distinct values being shown to 14
nested_summary_dg = gh_lrg_dg.nest_schema_w_values(
    grouping_paths=["type", "payload.release.upload_url"],
    nest_specs=[],
    aggregations=None
)

nested_summary_dg.print_guide_values(max_values=14)

# %%
# Running tests here and comparing to mongoDB, same data uploaded, distinct values being shown to 14
nested_summary_dg = gh_lrg_dg.nest_schema_w_values(
    grouping_paths=["type", "payload.release.id"],
    nest_specs=[],
    aggregations=None
)

nested_summary_dg.print_guide_values()
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 14, 'arr': 0}
#   root.payload: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 0}
#     [high-cardinality: >5 unique values]
#     root.payload.release: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
#       [high-cardinality: >5 unique values]
#       root.payload.release.id: {'int': 3765, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
#         [high-cardinality: >5 unique values]
#   root.type: {'int': 0, 'str': 1087835, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
#     Distinct values (top 5 of 14): [('PushEvent', 554612), ('CreateEvent', 116778), ('IssueCommentEvent', 108385), ('WatchEvent', 103723), ('IssuesEvent', 57375)]

# %%
# Running tests here and comparing to mongoDB, same data uploaded, distinct values being shown to 14
nested_summary_dg = gh_lrg_dg.nest_schema_w_values(
    grouping_paths=["payload.release", "payload.issue"],
    nest_specs=[],
    aggregations=None
)

nested_summary_dg.print_guide_values()
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 0}
#   root.payload: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 0}
#     [high-cardinality: >5 unique values]
#     root.payload.issue: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 1}
#       [high-cardinality: >5 unique values]
#       root.payload.issue.assignee: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
#         [high-cardinality: >5 unique values]
#         root.payload.issue.assignee.avatar_url: {'int': 0, 'str': 20373, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
#           [high-cardinality: >5 unique values]
#         root.payload.issue.assignee.events_url: {'int': 0, 'str': 20373, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
#           [high-cardinality: >5 unique values]
#         root.payload.issue.assignee.followers_url: {'int': 0, 'str': 20373, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
#           [high-cardinality: >5 unique values]
# ...

# %%
# Checking different dataset for possible schema manual observations
yelp_data_dg.print_guide_values()
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 10169368, 'arr': 0}
#   root.business_id: {'int': 0, 'str': 8181471, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
#     [high-cardinality: >1000 unique values]
#   root.name: {'int': 0, 'str': 2138243, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
#     [high-cardinality: >1000 unique values]
#   root.address: {'int': 0, 'str': 150230, 'float': 0, 'date': 116, 'obj': 0, 'arr': 0}
#     [high-cardinality: >1000 unique values]
#   root.city: {'int': 0, 'str': 150346, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
#     [high-cardinality: >1000 unique values]
#   root.state: {'int': 0, 'str': 150346, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
#     Distinct values (top 5 of 27): [('PA', 34039), ('FL', 26330), ('TN', 12056), ('IN', 11247), ('MO', 10913)]
#   root.postal_code: {'int': 0, 'str': 150346, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
#     [high-cardinality: >1000 unique values]
# ...

# %%
gh_lrg_dg.print_guide_values()
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1087835, 'arr': 0}
#   root.id: {'int': 0, 'str': 1087835, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
#     [high-cardinality: >1000 unique values]
#   root.type: {'int': 0, 'str': 1087835, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
#     Distinct values (top 5 of 14): [('PushEvent', 554612), ('CreateEvent', 116778), ('IssueCommentEvent', 108385), ('WatchEvent', 103723), ('IssuesEvent', 57375)]
#   root.actor: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1087835, 'arr': 0}
#     [high-cardinality: >1000 unique values]
#     root.actor.id: {'int': 1087835, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
#       [high-cardinality: >1000 unique values]
#     root.actor.login: {'int': 0, 'str': 1087834, 'float': 0, 'date': 1, 'obj': 0, 'arr': 0}
#       [high-cardinality: >1000 unique values]
#     root.actor.gravatar_id: {'int': 0, 'str': 1087835, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# ...

# %%
# New function created to check for co-occurrence 
gh_lrg_dg.find_cooccurring_paths()
# Out:
# {1087835: ['root',
#   'root.actor',
#   'root.actor.avatar_url',
#   'root.actor.gravatar_id',
#   'root.actor.id',
#   'root.actor.login',
#   'root.actor.url',
#   'root.created_at',
#   'root.id',
#   'root.payload',
#   'root.public',
#   'root.repo',
#   'root.repo.id',
#   'root.repo.name',
#   'root.repo.url',
#   'root.type'],
#  1004165: ['root.payload.commits.*',
#   'root.payload.commits.*.author',
#   'root.payload.commits.*.author.email',
#   'root.payload.commits.*.author.name',
#   'root.payload.commits.*.distinct',
#   'root.payload.commits.*.message',
#   'root.payload.commits.*.sha',
#   'root.payload.commits.*.url'],
#  554612: ['root.payload.before',
#   'root.payload.commits',
#   'root.payload.distinct_size',
#   'root.payload.head',
#   'root.payload.push_id',
#   'root.payload.size'],
#  328770: ['root.org',
#   'root.org.avatar_url',
#   'root.org.gravatar_id',
#   'root.org.id',
#   'root.org.login',
#   'root.org.url'],
#  165760: ['root.payload.issue',
# ...

# %%
# Print dataguide everynow and then for reference
gh_lrg_dg.print_guide_values(max_values=14)
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1087835, 'arr': 0}
#   root.id: {'int': 0, 'str': 1087835, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
#     [high-cardinality: >1000 unique values]
#   root.type: {'int': 0, 'str': 1087835, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
#     Distinct values (top 14 of 14): [('PushEvent', 554612), ('CreateEvent', 116778), ('IssueCommentEvent', 108385), ('WatchEvent', 103723), ('IssuesEvent', 57375), ('PullRequestEvent', 49785), ('ForkEvent', 34012), ('DeleteEvent', 19750), ('PullRequestReviewCommentEvent', 16035), ('GollumEvent', 11035), ('CommitCommentEvent', 7790), ('ReleaseEvent', 3765), ('MemberEvent', 3743), ('PublicEvent', 1047)]
#   root.actor: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1087835, 'arr': 0}
#     [high-cardinality: >1000 unique values]
#     root.actor.id: {'int': 1087835, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
#       [high-cardinality: >1000 unique values]
# ...

# %%
#Testing new function, checks for exact sum relationships up to k
res = gh_lrg_dg.find_exact_sum_relationships("root.type", k=3)
# Out:
#  Searching exact-sum relationships for path (using root.type):
# Found 14 distinct tracked values (showing up to first 50):
# PushEvent(554612), PullRequestEvent(49785), IssuesEvent(57375), CreateEvent(116778), IssueCommentEvent(108385), WatchEvent(103723), DeleteEvent(19750), ForkEvent(34012), PullRequestReviewCommentEvent(16035), CommitCommentEvent(7790), ReleaseEvent(3765), GollumEvent(11035), PublicEvent(1047), MemberEvent(3743)
#
#
# --- Checking 2-way combinations ---
#  PullRequestEvent(49785) + PullRequestReviewCommentEvent(16035) = payload.pull_request(65820)  [cross-path match]
#  PullRequestEvent(49785) + PullRequestReviewCommentEvent(16035) = payload.pull_request.url(65820)  [cross-path match]
#  PullRequestEvent(49785) + PullRequestReviewCommentEvent(16035) = payload.pull_request.id(65820)  [cross-path match]
#  PullRequestEvent(49785) + PullRequestReviewCommentEvent(16035) = payload.pull_request.html_url(65820)  [cross-path match]
# ...

# %%
yelp_data_dg.print_guide_values()
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 10169368, 'arr': 0}
#   root.business_id: {'int': 0, 'str': 8181471, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
#     [high-cardinality: >1000 unique values]
#   root.name: {'int': 0, 'str': 2138243, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
#     [high-cardinality: >1000 unique values]
#   root.address: {'int': 0, 'str': 150230, 'float': 0, 'date': 116, 'obj': 0, 'arr': 0}
#     [high-cardinality: >1000 unique values]
#   root.city: {'int': 0, 'str': 150346, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
#     [high-cardinality: >1000 unique values]
#   root.state: {'int': 0, 'str': 150346, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
#     Distinct values (top 5 of 27): [('PA', 34039), ('FL', 26330), ('TN', 12056), ('IN', 11247), ('MO', 10913)]
#   root.postal_code: {'int': 0, 'str': 150346, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
#     [high-cardinality: >1000 unique values]
# ...

# %%
# Showing what happen with high-cardinality
res = yelp_data_dg.find_exact_sum_relationships("root.business_id", k=5)
# Out:
# Path root.business_id is marked high-cardinality; cannot compute exact-sum relationships for its values.

# %%
# Showing what happen when not high-cardinality but could be not offering insights
res = yelp_data_dg.find_exact_sum_relationships("root.state", k=5)
# Out:
#  Searching exact-sum relationships for path (using root.state):
# Found 27 distinct tracked values (showing up to first 50):
# CA(5203), MO(10913), AZ(9912), PA(34039), TN(12056), FL(26330), IN(11247), LA(9924), AB(5573), NV(7715), ID(4467), DE(2265), IL(2145), NJ(8536), NC(1), CO(3), WA(2), HI(2), UT(1), TX(4), MT(1), MI(1), SD(1), XMS(1), MA(2), VI(1), VT(1)
#
#
# --- Checking 2-way combinations ---
#  NC(1) + CO(3) = TX(4)  [same path]
#  NC(1) + WA(2) = CO(3)  [same path]
#  NC(1) + HI(2) = CO(3)  [same path]
#  NC(1) + UT(1) = WA(2)  [same path]
#  NC(1) + UT(1) = HI(2)  [same path]
#  NC(1) + UT(1) = MA(2)  [same path]
#  NC(1) + MT(1) = WA(2)  [same path]
#  NC(1) + MT(1) = HI(2)  [same path]
#  NC(1) + MT(1) = MA(2)  [same path]
#  NC(1) + MI(1) = WA(2)  [same path]
#  NC(1) + MI(1) = HI(2)  [same path]
#  NC(1) + MI(1) = MA(2)  [same path]
#  NC(1) + SD(1) = WA(2)  [same path]
#  NC(1) + SD(1) = HI(2)  [same path]
#  NC(1) + SD(1) = MA(2)  [same path]
# ...

# %%
# Showing a possible relationship
res = yelp_data_dg.find_exact_sum_relationships("root.is_open", k=5)
# Out:
#  Searching exact-sum relationships for path (using root.is_open):
# Found 2 distinct tracked values (showing up to first 50):
# 0(30648), 1(119698)
#
#
# --- Checking 2-way combinations ---
#  0(30648) + 1(119698) = address(150346)  [cross-path match]
#  0(30648) + 1(119698) = city(150346)  [cross-path match]
#  0(30648) + 1(119698) = state(150346)  [cross-path match]
#  0(30648) + 1(119698) = postal_code(150346)  [cross-path match]
#  0(30648) + 1(119698) = latitude(150346)  [cross-path match]
#  0(30648) + 1(119698) = longitude(150346)  [cross-path match]
#  0(30648) + 1(119698) = is_open(150346)  [cross-path match]
#  0(30648) + 1(119698) = categories(150346)  [cross-path match]
#
# Found 8 exact-sum relationship(s).

# %%
# Showing a relationship, has meaning, but could be information overload
res = yelp_data_dg.find_exact_sum_relationships("root.attributes.DietaryRestrictions", k=3)
# Out:
#  Searching exact-sum relationships for path (using root.attributes.DietaryRestrictions):
# Found 11 distinct tracked values (showing up to first 50):
# ...

# %%
#another test
res = yelp_data_dg.find_exact_sum_relationships("root.average_stars", k=3)
# Out:
# Too many distinct values (401) to check combinations up to k=3.
# Reduce k or set max_keys_for_combinatorics higher. Attempting only 2-way combos.
#
#  Searching exact-sum relationships for path (using root.average_stars):
# Found 401 distinct tracked values (showing up to first 50):
# 3.91(5594), 3.74(3598), 3.32(2074), 4.27(5913), 3.54(3236), 3.85(4712), 2.75(6600), 3.73(5132), 4.04(3964), 3.4(14370), 4.0(102764), 3.89(6321), 4.51(1158), 3.08(2293), 4.29(8792), 3.75(14879), 4.15(4572), 3.84(3462), 4.11(7573), 3.6(10419), 3.98(2671), 3.52(2852), 4.06(5173), 3.93(5378), 3.81(4314), 3.5(35031), 4.33(26707), 3.69(4337), 3.41(2378), 3.79(4768), 3.53(3589), 3.63(6509), 3.62(3535), 3.33(17213), 3.61(2959), 3.26(1766), 3.87(3751), 3.19(1806), 3.57(6430), 3.06(1669), 4.69(2899), 2.95(1201), 4.43(10507), 3.77(4364), 3.92(5755), 4.17(9933), 3.45(3442), 3.9(5845), 4.5(39919), 3.28(1624)
#
# --- Checking 2-way combinations ---
# ...

# %%
# Showing default test of function with no params passed
res = gh_lrg_dg.find_exact_sum_relationships()
# Out:
# Path root.id is marked high-cardinality; cannot compute exact-sum relationships for its values.
#
#  Searching exact-sum relationships for path (using root.type):
# Found 14 distinct tracked values (showing up to first 50):
# PushEvent(554612), PullRequestEvent(49785), IssuesEvent(57375), CreateEvent(116778), IssueCommentEvent(108385), WatchEvent(103723), DeleteEvent(19750), ForkEvent(34012), PullRequestReviewCommentEvent(16035), CommitCommentEvent(7790), ReleaseEvent(3765), GollumEvent(11035), PublicEvent(1047), MemberEvent(3743)
#
#
# --- Checking 2-way combinations ---
#  PullRequestEvent(49785) + PullRequestReviewCommentEvent(16035) = payload.pull_request(65820)  [cross-path match]
#  PullRequestEvent(49785) + PullRequestReviewCommentEvent(16035) = payload.pull_request.url(65820)  [cross-path match]
#  PullRequestEvent(49785) + PullRequestReviewCommentEvent(16035) = payload.pull_request.id(65820)  [cross-path match]
# ...

# %%
# Testing new function, Shows distinct values for a path (or all paths with distinct values) along with their
# document counts and which other paths have the same document count
# The default is to not show the empty match -> [], but that can be also shown with 
# gh_lrg_dg.show_distinct_to_path_matches(skip_empty=False)
# Default function prints entire dataguide matches
gh_lrg_dg.show_distinct_to_path_matches()
# Out:
# Distinct values at 'root.type' with matching paths by document count:
#   PushEvent: 554612 -> ['root.payload.push_id', 'root.payload.size', 'root.payload.distinct_size', 'root.payload.head', 'root.payload.before', 'root.payload.commits']
#   CreateEvent: 116778 -> ['root.payload.master_branch', 'root.payload.description']
#   IssueCommentEvent: 108385 -> ['root.payload.comment.issue_url']
#   PullRequestEvent: 49785 -> ['root.payload.number', 'root.payload.pull_request.merged', 'root.payload.pull_request.mergeable', 'root.payload.pull_request.mergeable_state', 'root.payload.pull_request.merged_by', 'root.payload.pull_request.comments', 'root.payload.pull_request.review_comments', 'root.payload.pull_request.commits', 'root.payload.pull_request.additions', 'root.payload.pull_request.deletions', 'root.payload.pull_request.changed_files']
# ...

# %%
#Testing/showing can be filtered to a specific path and top_n matches can be show, up to max
gh_lrg_dg.show_distinct_to_path_matches(path="root.type", top_n=14, skip_empty=True)
# Out:
# Distinct values at 'root.type' with matching paths by document count:
#   PushEvent: 554612 -> ['root.payload.push_id', 'root.payload.size', 'root.payload.distinct_size', 'root.payload.head', 'root.payload.before', 'root.payload.commits']
#   CreateEvent: 116778 -> ['root.payload.master_branch', 'root.payload.description']
#   IssueCommentEvent: 108385 -> ['root.payload.comment.issue_url']
#   PullRequestEvent: 49785 -> ['root.payload.number', 'root.payload.pull_request.merged', 'root.payload.pull_request.mergeable', 'root.payload.pull_request.mergeable_state', 'root.payload.pull_request.merged_by', 'root.payload.pull_request.comments', 'root.payload.pull_request.review_comments', 'root.payload.pull_request.commits', 'root.payload.pull_request.additions', 'root.payload.pull_request.deletions', 'root.payload.pull_request.changed_files']
# ...

# %%
yelp_data_dg.find_cooccurring_paths()
# Out:
# {8978177: ['root.cool', 'root.funny', 'root.useful'],
#  2138243: ['root.name', 'root.review_count'],
#  1987897: ['root.average_stars',
#   'root.compliment_cool',
#   'root.compliment_cute',
#   'root.compliment_funny',
#   'root.compliment_hot',
#   'root.compliment_list',
#   'root.compliment_more',
#   'root.compliment_note',
#   'root.compliment_photos',
#   'root.compliment_plain',
#   'root.compliment_profile',
#   'root.compliment_writer',
#   'root.elite',
#   'root.fans',
#   'root.friends',
#   'root.yelping_since'],
#  150346: ['root.address',
#   'root.attributes',
#   'root.categories',
#   'root.city',
#   'root.hours',
#   'root.is_open',
#   'root.latitude',
#   'root.longitude',
#   'root.postal_code',
#   'root.state']}

# %%
#show_distinct_to_path_matches but on yelp dataset
yelp_data_dg.show_distinct_to_path_matches()
# Out:
# Distinct values at 'root.state' with matching paths by document count:
#
# Distinct values at 'root.stars' with matching paths by document count:
#
# Distinct values at 'root.is_open' with matching paths by document count:
#
# Distinct values at 'root.attributes.ByAppointmentOnly' with matching paths by document count:
#
# Distinct values at 'root.attributes.BusinessAcceptsCreditCards' with matching paths by document count:
#
# Distinct values at 'root.attributes.BikeParking' with matching paths by document count:
#
# Distinct values at 'root.attributes.RestaurantsPriceRange2' with matching paths by document count:
#
# Distinct values at 'root.attributes.CoatCheck' with matching paths by document count:
#
# Distinct values at 'root.attributes.RestaurantsTakeOut' with matching paths by document count:
#
# Distinct values at 'root.attributes.RestaurantsDelivery' with matching paths by document count:
#
# ...
