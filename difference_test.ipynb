# %%
from DataGuidePathClass import DataGuidePath # Importing needed classes
# dg = dataguide

# %%
# Docs to be used for easier test to follow
doc1 = { "sport": "soccer", "difficulty_lvl": 3, "num_balls": 1 } # original base doc
doc2 = { "sport": "dodgeball", "difficulty_lvl": 1, "num_balls": 6 } # original base doc
doc3 = { "sport": "swimming", "difficulty_lvl": 8, "involves_water": "no" } # additional key and value
doc4 = { "sport": "swimming", "difficulty_lvl": 8, "involves_water": "yes" } # additional key and value
doc5 = { "sport": "tennis", "difficulty_lvl": 5, "num_balls": "three" } # num_balls is str type instead of int
doc6 = { "sport": "soccer", "difficulty_lvl": 3, "num_balls": 1, "field_type": "grass" } # additional key and value
doc7 = { "f_name": "John", "l_name": "Smith", "age": 25} # unrelated doc
doc8 = { "sport": "dodgeball", "num_balls": 6 , "difficulty_lvl": 3} # path in different order from base doc
doc9 = { "f_name": "John", "l_name": "Smith", "age": 25, "sport": "soccer"} # different schema with 1 related path
doc10 = { "sport": "basketball", "difficulty_lvl": 6, "num_balls": 1 }
doc11 = { "sport": "soccer", "difficulty_lvl": 3, "num_balls": [1, 2, 3] } # original base doc
doc12 = { "sport": "dodgeball", "difficulty_lvl": 1, "num_balls": 6 } # original base doc
doc13 = { "sport": "baseball", "difficulty_lvl": 4, "num_balls": 5 }
doc14 = { "sport": "volleyball", "difficulty_lvl": 2, "num_balls": 1 }
doc15 = { "num_balls": 1, "sport": "golf", "difficulty_lvl": 7 } #(Different order)
doc16 = { "sport": "hockey", "num_balls": 1, "difficulty_lvl": 9 }#(Different order)
doc17 = { "sport": "badminton", "difficulty_lvl": 2, "num_balls": 1 }
doc18 = { "sport": "running", "difficulty_lvl": 3, "num_balls": 0 }
doc19 = { "sport": "skiing", "difficulty_lvl": 7, "involves_water": "no" }
doc20 = { "sport": "water polo", "difficulty_lvl": 9, "involves_water": "yes" }
doc21 = { "sport": "tennis", "difficulty_lvl": 5, "num_balls": 4 }
doc22 = { "sport": "soccer", "difficulty_lvl": 3, "num_balls": "one" } #(Value type change)
doc23 = { "sport": "boxing", "difficulty_lvl": 8, "equipment": ["gloves", "mouthguard"], "event_date": "2024-12-31" } #(Different order) (Also a date type)
doc24 = { "sport": "baseball", "difficulty_lvl": 4, "num_balls": [1, 2, 3, 4] } #(Value type change to array)
doc25 = { "sport": "fencing", "difficulty_lvl": 6, "num_balls": 0 }
doc26 = { "sport": "archery", "difficulty_lvl": 5, "num_balls": 0 }
doc27 = { "sport": "rock climbing", "difficulty_lvl": 8, "num_balls": None } #(Null value)
doc28 = { "sport": "dodgeball", "difficulty_lvl": 1, "num_balls": 6.5 } #(Float value, new type)
doc29 = { "sport": "cycling", "difficulty_lvl": 4, "involves_water": "no" }
doc30 = { "sport": "diving", "difficulty_lvl": 7, "involves_water": "yes" }
doc31 = { "sport": "handball", "difficulty_lvl": 3, "num_balls": 1 }
doc32 = { "sport": "football", "difficulty_lvl": 6, "num_balls": 1, "is_team_sport": True } #(New key: is_team_sport)
doc33 = { "sport": "boxing", "difficulty_lvl": 8, "equipment": ["gloves", "mouthguard"] }# (New key: equipment)
doc34 = { "sport": "gymnastics", "difficulty_lvl": 10, "judged": True } #(New key: judged)
doc35 = { "sport": "karate", "difficulty_lvl": 7, "indoor_sport": False } #(New key: indoor_sport)
doc36 = { "sport": "surfing", "difficulty_lvl": 9, "involves_water": "yes", "board_type": "longboard" } #(New key: board_type)
doc37 = { "sport": "curling", "difficulty_lvl": 1, "num_balls": 8, "requires_ice": True, "event_date": "2025-01-15" } #(New key: requires_ice)
doc38 = { "sport": "lacrosse", "difficulty_lvl": 7, "num_players": 10, "num_balls": 1 } #(New key: num_players)
doc39 = { "sport": "badminton", "difficulty_lvl": 2, "num_balls": 1, "requires_net": True } #(New key: requires_net)
doc40 = { "sport": "darts", "difficulty_lvl": 3, "num_balls": 3, "max_score": 501 } #(New key: max_score)

# %%
# Creating two dgs indentical paths and docs, 1 each
dg_1 =  DataGuidePath()
dg_1.insert_document(doc1)
dg_2 = DataGuidePath()
dg_2.insert_document(doc1)

# %%
# showing what each dg has
print("dg1:")
dg_1.print_guide()
print("dg2:")
# showing what each dg has
dg_2.print_guide()
# Out:
# dg1:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 0}
# root.sport: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.difficulty_lvl: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.num_balls: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# dg2:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 0}
# root.sport: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.difficulty_lvl: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.num_balls: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}

# %%
# Case 1.1 Difference is Empty, identical dgs
# testing difference for two identical dgs
result_diff_dg = dg_1.difference_beta(dg_2, mode="lower_bound")
result_diff_dg.print_guide()
# works correctly, all counters are 0 and not paths since dg_1 has no paths that don't exist in dg-2
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}

# %%
# Case 1.2 DG(A) and DG(B) are disjoint
dg_1 =  DataGuidePath()
dg_1.insert_document([doc1, doc2]) # no matching paths to dg2
dg_2 = DataGuidePath()
dg_2.insert_document([doc7, doc8])
result_diff_dg = dg_1.difference_beta(dg_2, mode="lower_bound")
result_diff_dg.print_guide()
# expected output is obj:1, because we are using "lower_bound", "upper_bound would yield obj:2"
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 0}
# root.sport: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.difficulty_lvl: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.num_balls: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}

# %%
# Same test as above but in reverse call order
dg_1 =  DataGuidePath()
dg_1.insert_document([doc1, doc2]) # no matching paths to dg2
dg_2 = DataGuidePath()
dg_2.insert_document([doc7, doc8])
result_diff_dg = dg_2.difference_beta(dg_1, mode="lower_bound")
result_diff_dg.print_guide()
# expected output is obj:1 because we are using "lower_bound", "upper_bound would yield obj:2"
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 0}
# root.f_name: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.l_name: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.age: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}

# %%
# Same test as above but using "upper_bound"
dg_1 =  DataGuidePath()
dg_1.insert_document([doc1, doc2]) # no matching paths to dg2
dg_2 = DataGuidePath()
dg_2.insert_document([doc7, doc8])
result_diff_dg = dg_2.difference_beta(dg_1, mode="upper_bound")
result_diff_dg.print_guide()
# expected output is obj:2 because we are using "upper_bound"
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 2, 'arr': 0}
# root.f_name: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.l_name: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.age: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}

# %%
# Case 1.1 Difference is Empty cont, identical dgs, more complex
dg_1 =  DataGuidePath()
dg_1.insert_document([doc2, doc3, doc4])
dg_2 = DataGuidePath()
dg_2.insert_document([doc3, doc2, doc4])
result_diff_dg = dg_1.difference_beta(dg_2, mode="lower_bound")
result_diff_dg.print_guide()
# expected output is all 0's since dgs match, difference is all 0's
# SPECIAL CASE NEED TO MAKE THIS SHOW 1
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}

# %%
# Case 2.1 A is a subset of B -all documents
# new dg's with only one path different
dg_1 =  DataGuidePath()
dg_1.insert_document(doc7)
dg_2 = DataGuidePath()
dg_2.insert_document(doc9) # doc9 has one more path than doc7, all other paths the same

# %%
# Case 2.1 A is a subset of B -all documents
# testing current difference, WORKS CORRECTLY since path d does exist in dg_2 and not in dg_1
result_diff_dg = dg_2.difference_beta(dg_1, mode="lower_bound")
result_diff_dg.print_guide()
# Works correctly, expected output is obj:1 since we have 1 doc in each dg and dg2 has 1 unique path
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 0}
# root.sport: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}

# %%
# Testing the same as above but in different call order
result_diff_dg = dg_1.difference_beta(dg_2, mode="lower_bound")
result_diff_dg.print_guide()
# Works correctly, dg_1 has no unique paths, dg_2 contains all paths in dg_1,
# Thus we expect that 0 docs will be in dg1 that are not in dg2
# Eventhough the doc in dg1 does not match the doc in dg2
# This is because it reads which docs are in dg1 but not in dg2 (or perhaps should be special case??)
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}

# %%
# Case 2.1 DG(A) and DG(B) have the same paths.
# Adding path to dg1 that exists in dg2, bringing total docs to 2 in dg1 and 1 doc in dg2
dg_1 =  DataGuidePath()
dg_1.insert_document(doc7)
dg_2 = DataGuidePath()
dg_2.insert_document(doc9) # contains path root.sport
dg_1.insert_document([{"sport": "tennis"}]) # adding doc with path root.sport
result_diff_dg = dg_1.difference_beta(dg_2, mode="lower_bound")
result_diff_dg.print_guide()
# The output expected is root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 0}
# This is because we have all the same paths, but dg1 has two docs, but dg2 has one doc, so
# At least one doc in dg1 should not match dg2.
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 0}

# %%
# Same test as above but with upper_bound
result_diff_dg = dg_1.difference_beta(dg_2, mode="upper_bound")
result_diff_dg.print_guide()
# This time root: {obj:2} is expected
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 2, 'arr': 0}

# %%
# Case 2.2 DG(B) has paths that are not in DG(A)
# Case more docs, using lower_bound
dg_1 =  DataGuidePath()
dg_1.insert_document([doc7, doc8])
dg_2 = DataGuidePath()
dg_2.insert_document([doc7, doc8, doc9]) # doc7, doc8, doc9 all have some similar paths, but diff schema
result_diff_dg = dg_2.difference_beta(dg_1, mode="lower_bound")
result_diff_dg.print_guide() 
# We can see above that 1 doc more is found in dg2, thus ideally we want to see 1 doc in difference
# With lower_bound we guarantee in a minimum difference, so at least 1 document in dg1 is different
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 0}
# root.f_name: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.l_name: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.age: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.sport: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}

# %%
# showing what each dg has from above
print("dg1:")
dg_1.print_guide()
print("dg2:")
dg_2.print_guide()
# Out:
# dg1:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 2, 'arr': 0}
# root.f_name: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.l_name: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.age: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.sport: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.num_balls: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.difficulty_lvl: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# dg2:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 3, 'arr': 0}
# root.f_name: {'int': 0, 'str': 2, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.l_name: {'int': 0, 'str': 2, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.age: {'int': 2, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.sport: {'int': 0, 'str': 2, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# ...

# %%
# Case 2.2 DG(B) has paths that are not in DG(A)
# Case more docs, using upper_bound
dg_1 =  DataGuidePath()
dg_1.insert_document([doc7, doc8])
dg_2 = DataGuidePath()
dg_2.insert_document([doc7, doc8, doc9]) # doc7, doc8, doc9 all have some similar paths, but diff schema
result_diff_dg = dg_2.difference_beta(dg_1, mode="upper_bound")
result_diff_dg.print_guide() 
# With upper_bound, because paths can be in all sorts of orders, all 3 docs could be unique
# Upper_bound should output obj:2, paths and counters also appear correct 
# "root.f_name: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.l_name: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.age: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.sport: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}"
# This is because these 4 paths above can be guaranteed to appear at least that number of times uniquely,
# and thus are part of the difference.
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 3, 'arr': 0}
# root.f_name: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.l_name: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.age: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.sport: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}

# %%
# same test as above but calling in reverse order
dg_1 =  DataGuidePath()
dg_1.insert_document([doc7, doc8])
dg_2 = DataGuidePath()
dg_2.insert_document([doc7, doc8, doc9]) # doc7, doc8, doc9 all have some similar paths, but diff schema
result_diff_dg = dg_1.difference_beta(dg_2, mode="lower_bound")
result_diff_dg.print_guide() 
# because dg1 is a subset fo dg2 for all documents, expected output is all 0's
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}

# %%
# testing with array specifically
dg_1 =  DataGuidePath()
dg_1.insert_document([doc1, doc2, doc5]) # root.num_balls {int:1} appears 3 times
dg_2 = DataGuidePath()
dg_2.insert_document([doc11, doc12, doc5]) # root.num_balls {int:1} appears 2 times, # root.num_balls {arr:1} appears 1 time
result_diff_dg = dg_1.difference_beta(dg_2, mode="lower_bound")
result_diff_dg.print_guide()
# expected output is root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 0}
# root.num_balls: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 0}
# root.num_balls: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}

# %%
# testing with array specifically, calling in reverse order
dg_1 =  DataGuidePath()
dg_1.insert_document([doc1, doc2, doc5])
dg_2 = DataGuidePath()
dg_2.insert_document([doc11, doc12, doc5])
result_diff_dg = dg_2.difference_beta(dg_1, mode="lower_bound")
result_diff_dg.print_guide()
# expected output is: root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 0}
# root.num_balls: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 1}
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 0}
# root.num_balls: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 1}

# %%
# testing using more counters, this also shows core root.sport, root.difficulty_lvl, and root.num_balls appear twice in both dgs.
dg_1 =  DataGuidePath()
dg_1.insert_document([doc1, doc1, doc1, doc7]) # doc7 has unique path root.age
dg_2 = DataGuidePath()
# doc11 contains one unique path, array
dg_2.insert_document([doc1, doc11, doc6]) # doc6 contains all paths as doc1 + one additional unique path
print("dg1 for reference:")
dg_1.print_guide()
print("dg2 for reference:")
dg_2.print_guide()
print("\n")
print("result of diff dg:")
result_diff_dg = dg_1.difference_beta(dg_2, mode="lower_bound")
result_diff_dg.print_guide()
# using lower bound because doc6 contains all paths doc1 has, only 1 counter is left, and one counter for doc7, so max of (1,1) is 1
# accurately reflect that dg1 has one unique document
# Out:
# dg1 for reference:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 4, 'arr': 0}
# root.sport: {'int': 0, 'str': 3, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.difficulty_lvl: {'int': 3, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.num_balls: {'int': 3, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.f_name: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.l_name: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.age: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# dg2 for reference:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 3, 'arr': 0}
# root.sport: {'int': 0, 'str': 3, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.difficulty_lvl: {'int': 3, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.num_balls: {'int': 2, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 1}
# root.num_balls.*: {'int': 3, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# ...

# %%
# same as above but calling in reverse
dg_1 =  DataGuidePath()
dg_1.insert_document([doc1, doc1, doc1, doc7]) # doc7 has unique path root.age
dg_2 = DataGuidePath()
# doc11 contains one unique path, array
dg_2.insert_document([doc1, doc11, doc6]) # doc6 contains all paths as doc1 + one additional unique path
result_diff_dg = dg_2.difference_beta(dg_1, mode="lower_bound")
result_diff_dg.print_guide()
# Although we can see doc11 and doc6 are different, at most lower_bound can determine at least 1 document will be different
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 0}
# root.num_balls: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 1}
# root.field_type: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}

# %%
# same tests as above but showing output for upper_bound
dg_1 =  DataGuidePath()
dg_1.insert_document([doc1, doc1, doc1, doc7]) # doc7 has unique path root.age
dg_2 = DataGuidePath()
# doc11 contains one unique path, array
dg_2.insert_document([doc1, doc11, doc6]) # doc6 contains all paths as doc1 + one additional unique path
result_diff_dg = dg_1.difference_beta(dg_2, mode="upper_bound")
result_diff_dg.print_guide()
# output expected is obj:4 b/c dg1 => root.num_balls int:3, dg2 => root.num_balls int:2 diff = 1,
# root.age exists in dg1 but not dg2 = 1, root.f_name exists in dg1 but not dg2 = 1, 
# root.l_name exists in dg1 but not dg2 = . 1+1+1+1 = 4
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 4, 'arr': 0}
# root.num_balls: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.f_name: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.l_name: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.age: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}

# %%
# same tests as above, calling in reverse, showing output for upper_bound
dg_1 =  DataGuidePath()
dg_1.insert_document([doc1, doc1, doc1, doc7]) # doc7 has unique path root.age
dg_2 = DataGuidePath()
# doc11 contains one unique path, array
dg_2.insert_document([doc1, doc11, doc6]) # doc6 contains all paths as doc1 + one additional unique path
result_diff_dg = dg_2.difference_beta(dg_1, mode="upper_bound")
result_diff_dg.print_guide()
# we expect obj:2 b/c root.num_balls arr:1 appears in dg2 but not dg1,
# root.field_type exists in dg1 but not dg2, so 1+1 =2 documents that could exist in dg2 but not dg1
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 2, 'arr': 0}
# root.num_balls: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 1}
# root.field_type: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}

# %%
#END

# %%
# Core tests:
# lower_bound: guaranteed minimum unique docs
# upper_bound: optimistic maximum unique docs
# Cores: root.sport:[str] , root.difficulty_lvl[str]:
# Core Test 1, upper_bound
dg_1 =  DataGuidePath()
dg_1.insert_document([doc1, doc2])
dg_2 = DataGuidePath()
dg_2.insert_document([doc5, doc6])
result_diff_dg = dg_2.difference_beta(dg_1, mode="upper_bound")
result_diff_dg.print_guide()
# Optimistcally since dg2 contains two unique paths, we could have completely disjoint dgs
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 2, 'arr': 0}
# root.num_balls: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.field_type: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}

# %%
# Core Test 1, lower_bound
dg_1 =  DataGuidePath()
dg_1.insert_document([doc1, doc2])
dg_2 = DataGuidePath()
dg_2.insert_document([doc5, doc6])
result_diff_dg = dg_2.difference_beta(dg_1, mode="lower_bound")
result_diff_dg.print_guide()
# Accurately shows that we will have 1 unique doc with paths root.num_balls or root.field_type
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 0}
# root.num_balls: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.field_type: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}

# %%
# Same as above but with mid test
dg_1 =  DataGuidePath()
dg_1.insert_document([doc1, doc2])
dg_2 = DataGuidePath()
dg_2.insert_document([doc5, doc6])
result_diff_dg = dg_2.difference_beta(dg_1, mode="mid")
result_diff_dg.print_guide()
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 2, 'arr': 0}
# root.num_balls: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.field_type: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}

# %%
# Same tests as above but in reverse calling order, upper_bound
dg_1 =  DataGuidePath()
dg_1.insert_document([doc1, doc2])
dg_2 = DataGuidePath()
dg_2.insert_document([doc5, doc6])
result_diff_dg = dg_1.difference_beta(dg_2, mode="upper_bound")
result_diff_dg.print_guide()
# Optimistcally since dg1 contains only 1 unique paths, we could have one unique document
# with the path root.num_balls, which is unique to dg1
# every other path appears twice, as they does in dg2
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 0}
# root.num_balls: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}

# %%
# Same tests as above but in reverse calling order, lower_bound
dg_1 =  DataGuidePath()
dg_1.insert_document([doc1, doc2])
dg_2 = DataGuidePath()
dg_2.insert_document([doc5, doc6])
result_diff_dg = dg_1.difference_beta(dg_2, mode="lower_bound")
result_diff_dg.print_guide()
# Accurately shows that we will have 1 unique doc with paths root.num_balls
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 0}
# root.num_balls: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}

# %%
# Same as above but with mid test
dg_1 =  DataGuidePath()
dg_1.insert_document([doc1, doc2])
dg_2 = DataGuidePath()
dg_2.insert_document([doc5, doc6])
result_diff_dg = dg_1.difference_beta(dg_2, mode="mid")
result_diff_dg.print_guide()
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 0}
# root.num_balls: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}

# %%
# More complex test, and using array in one doc
# Cores: root.sport:[str] , root.difficulty_lvl[str]:
# Core Test 2, upper_bound
dg_1 =  DataGuidePath()
dg_1.insert_document([doc1, doc2, doc3])
dg_2 = DataGuidePath()
dg_2.insert_document([doc4, doc5, doc6, doc11])
result_diff_dg = dg_1.difference_beta(dg_2, mode="upper_bound")
result_diff_dg.print_guide()
# Accurate because both dg's have the core, 
# that only leaves root.num_balls[str] appearing twice in dg1, but once in dg1, 
# and root.involves_water[str] once in dg1 and once in dg2 max(1-1, 2-1) = 1
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 0}
# root.num_balls: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}

# %%
# Same as above but lower_bound "guaranteed"
dg_1 =  DataGuidePath()
dg_1.insert_document([doc1, doc2, doc3])
dg_2 = DataGuidePath()
dg_2.insert_document([doc4, doc5, doc6, doc11])
result_diff_dg = dg_1.difference_beta(dg_2, mode="lower_bound")
result_diff_dg.print_guide()
# Based on the dg's we can at most guarantee one unique document 
# because the paths in dg1 are a subset of dg2, but we have 4-3 docs =1
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 0}
# root.num_balls: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}

# %%
# Same as above but with mid test
dg_1 =  DataGuidePath()
dg_1.insert_document([doc1, doc2, doc3])
dg_2 = DataGuidePath()
dg_2.insert_document([doc4, doc5, doc6, doc11])
result_diff_dg = dg_1.difference_beta(dg_2, mode="mid")
result_diff_dg.print_guide()
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 0}
# root.num_balls: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}

# %%
# Same as above but calling in reverse, upper_bound "optimistic"
dg_1 =  DataGuidePath()
dg_1.insert_document([doc1, doc2, doc3])
dg_2 = DataGuidePath()
dg_2.insert_document([doc4, doc5, doc6, doc11])
result_diff_dg = dg_2.difference_beta(dg_1, mode="upper_bound")
result_diff_dg.print_guide()
# There are 3 unique paths in dg2 + 2 core paths that appears more than in dg1 based on document count
# Unique paths: root.field_type[str], root.num_balls[arr], root.num_balls[str]
# the three unique paths could be seperately in doc4, doc5, and doc6 for example
# and the additional core paths would make up doc11, so max 4 documents
# the actual algorithm calculates min(total_docs=4, sum(exclusive paths=5)) = 4 because
# we cannot have more than the total docs in the dg
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 4, 'arr': 0}
# root.sport: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.difficulty_lvl: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.num_balls: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 1}
# root.field_type: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}

# %%
# Same as above but lower_bound "guaranteed"
dg_1 =  DataGuidePath()
dg_1.insert_document([doc1, doc2, doc3])
dg_2 = DataGuidePath()
dg_2.insert_document([doc4, doc5, doc6, doc11])
result_diff_dg = dg_2.difference_beta(dg_1, mode="lower_bound")
result_diff_dg.print_guide()
# Because the paths in dg1 are a subset of dg2, at most we can have 4docs- 3docs = 1 guaranteed doc
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 0}
# root.sport: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.difficulty_lvl: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.num_balls: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 1}
# root.field_type: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}

# %%
# Testing mid, mid is just the lb+up +1 // 2 = rounded up
dg_1 =  DataGuidePath()
dg_1.insert_document([doc1, doc2, doc3])
dg_2 = DataGuidePath()
dg_2.insert_document([doc4, doc5, doc6, doc11])
result_diff_dg = dg_2.difference_beta(dg_1, mode="mid")
result_diff_dg.print_guide()
# Because lower bound is 1, and upperbound is 4, the midpoint is 3.
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 3, 'arr': 0}
# root.sport: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.difficulty_lvl: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.num_balls: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 1}
# root.field_type: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}

# %%
# Testing Float value types lower_bound
dg_1 = DataGuidePath()
dg_1.insert_document([doc27]) # include root.num_balls[null/None]
dg_2 = DataGuidePath()
dg_2.insert_document([doc28])
result_diff_dg = dg_2.difference_beta(dg_1, mode="lower_bound")
result_diff_dg.print_guide()
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 0}
# root.num_balls: {'int': 0, 'str': 0, 'float': 1, 'date': 0, 'obj': 0, 'arr': 0}

# %%
# Testing Float value types upper_bound
dg_1 = DataGuidePath()
dg_1.insert_document([doc27])
dg_2 = DataGuidePath()
dg_2.insert_document([doc28])
result_diff_dg = dg_2.difference_beta(dg_1, mode="upper_bound")
result_diff_dg.print_guide()
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 0}
# root.num_balls: {'int': 0, 'str': 0, 'float': 1, 'date': 0, 'obj': 0, 'arr': 0}

# %%
# Testing Float value type mid
dg_1 = DataGuidePath()
dg_1.insert_document([doc27])
dg_2 = DataGuidePath()
dg_2.insert_document([doc28])
result_diff_dg = dg_2.difference_beta(dg_1, mode="mid")
result_diff_dg.print_guide()
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 0}
# root.num_balls: {'int': 0, 'str': 0, 'float': 1, 'date': 0, 'obj': 0, 'arr': 0}

# %%
# Testing None types lower_bound
dg_1 = DataGuidePath()
dg_1.insert_document([doc27]) # include root.num_balls[null/None]
dg_2 = DataGuidePath()
dg_2.insert_document([doc28])
result_diff_dg = dg_1.difference_beta(dg_2, mode="lower_bound")
result_diff_dg.print_guide()
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 0}
# root.num_balls: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0, 'NoneType': 1}

# %%
# Testing None types upper_bound
dg_1 = DataGuidePath()
dg_1.insert_document([doc27]) # include root.num_balls[null/None]
dg_2 = DataGuidePath()
dg_2.insert_document([doc28])
result_diff_dg = dg_1.difference_beta(dg_2, mode="upper_bound")
result_diff_dg.print_guide()
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 0}
# root.num_balls: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0, 'NoneType': 1}

# %%
# Testing None types mid
dg_1 = DataGuidePath()
dg_1.insert_document([doc27]) # include root.num_balls[null/None]
dg_2 = DataGuidePath()
dg_2.insert_document([doc28])
result_diff_dg = dg_1.difference_beta(dg_2, mode="mid")
result_diff_dg.print_guide()
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 0}
# root.num_balls: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0, 'NoneType': 1}

# %%
# Testing date type JSON DOES NOT HAVE A DATE TYPE!!!!???
dg_1 = DataGuidePath()
dg_1.insert_document([doc36])
dg_2 = DataGuidePath()
dg_2.insert_document([doc37])
result_diff_dg = dg_2.difference_beta(dg_1, mode="mid")
result_diff_dg.print_guide()
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 0}
# root.num_balls: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.requires_ice: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.event_date: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}

# %%
# Testing date type in reverse, 
dg_1 = DataGuidePath()
dg_1.insert_document([doc36])
dg_2 = DataGuidePath()
dg_2.insert_document([doc37])
result_diff_dg = dg_1.difference_beta(dg_2, mode="mid")
result_diff_dg.print_guide()
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 0}
# root.involves_water: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.board_type: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}

# %%
# Testing date type in reverse, 
dg_1 = DataGuidePath()
dg_1.insert_document([doc36])
dg_2 = DataGuidePath()
dg_2.insert_document([doc37]) # date ()JSON does not have date type
result_diff_dg = dg_1.difference_beta(dg_2, mode="lower_bound")
result_diff_dg.print_guide()
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 0}
# root.involves_water: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.board_type: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}

# %%
# Testing lower_bound vs upper_bound vs mid
print("Lower_bound:")
dg_1 = DataGuidePath()
dg_1.insert_document([doc1, doc2, doc5, doc16, doc36])
dg_2 = DataGuidePath()
dg_2.insert_document([doc2, doc5, doc12, doc13, doc37]) 
result_diff_dg = dg_1.difference_beta(dg_2, mode="lower_bound")
result_diff_dg.print_guide()
print("total_docs: " + str(result_diff_dg.total_docs))
print('\n' + 'Upper_bound:')
dg_1 = DataGuidePath()
dg_1.insert_document([doc1, doc2, doc5, doc16, doc36])
dg_2 = DataGuidePath()
dg_2.insert_document([doc2, doc5, doc12, doc13, doc37]) 
result_diff_dg = dg_1.difference_beta(dg_2, mode="upper_bound")
result_diff_dg.print_guide()
print("total_docs: " + str(result_diff_dg.total_docs))
print('\n' + "mid:")
dg_1 = DataGuidePath()
dg_1.insert_document([doc1, doc2, doc5, doc16, doc36])
dg_2 = DataGuidePath()
dg_2.insert_document([doc2, doc5, doc12, doc13, doc37]) 
result_diff_dg = dg_1.difference_beta(dg_2, mode="mid")
result_diff_dg.print_guide()
print("total_docs: " + str(result_diff_dg.total_docs))
# Out:
# Lower_bound:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 0}
# root.involves_water: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.board_type: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# total_docs: 1
#
# Upper_bound:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 2, 'arr': 0}
# root.involves_water: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.board_type: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# total_docs: 2
#
# mid:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 2, 'arr': 0}
# root.involves_water: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.board_type: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# total_docs: 2

# %%
# Testing lower_bound vs upper_bound vs mid
dg1_list = [doc1, doc7, doc10, doc12, doc30, doc31, doc32, doc34]
dg2_list = [doc7, doc9, doc12, doc30, doc31, doc32, doc35]

# frozenset is a hashable version of a set
set1 = {frozenset(d.items()) for d in dg1_list}
set2 = {frozenset(d.items()) for d in dg2_list}

total_diff_docs = len(set1 - set2) 

print("Lower_bound:")
dg_1 = DataGuidePath()
dg_1.insert_document(dg1_list)
dg_2 = DataGuidePath()
dg_2.insert_document(dg2_list) 
result_diff_dg = dg_1.difference_beta(dg_2, mode="lower_bound")
print("total_docs: " + str(result_diff_dg.total_docs))

print('\n' + 'Upper_bound:')
dg_1 = DataGuidePath()
dg_1.insert_document(dg1_list)
dg_2 = DataGuidePath()
dg_2.insert_document(dg2_list) 
result_diff_dg = dg_1.difference_beta(dg_2, mode="upper_bound")
print("total_docs: " + str(result_diff_dg.total_docs))

print('\n' + "mid:")
dg_1 = DataGuidePath()
dg_1.insert_document(dg1_list)
dg_2 = DataGuidePath()
dg_2.insert_document(dg2_list) 
result_diff_dg = dg_1.difference_beta(dg_2, mode="mid")
print("total_docs: " + str(result_diff_dg.total_docs))
print("actual diff docs: " + str(total_diff_docs))
# Out:
# Lower_bound:
# total_docs: 2
#
# Upper_bound:
# total_docs: 6
#
# mid:
# total_docs: 4
# actual diff docs: 3

# %%
# First larger test where dg1 is size 5 (random from docs 1-40), and dg2 is size 5 (random from docs 1-40)
# This test essentially mostly when the dg's are similar schema but unlikely to be the same docs
import random

random.seed(10)  

def make_hashable(value):
    if isinstance(value, dict):
        return frozenset((k, make_hashable(v)) for k, v in value.items())
    elif isinstance(value, list):
        return tuple(make_hashable(v) for v in value)
    else:
        return value

# since doc1–doc40 are already defined
all_docs = [globals()[f"doc{i}"] for i in range(1, 41)]

# tracking
stats = {"lower_bound": 0, "upper_bound": 0, "mid": 0}
tie_stats = {} 

num_iterations = 1000

for i in range(num_iterations):
    
    n1 = random.randint(5,6)
    n2 = random.randint(5,6)
    dg1_list = random.sample(all_docs, k=n1)
    dg2_list = random.sample(all_docs, k=n2)

    # convert to hashable for accurate set difference
    set1 = {make_hashable(d) for d in dg1_list}
    set2 = {make_hashable(d) for d in dg2_list}
    total_diff_docs = len(set1 - set2)

    # compute all three modes
    estimates = {}
    for mode in ["lower_bound", "upper_bound", "mid"]:
        dg_1 = DataGuidePath()
        dg_1.insert_document(dg1_list)
        dg_2 = DataGuidePath()
        dg_2.insert_document(dg2_list)
        result_diff_dg = dg_1.difference_beta(dg_2, mode=mode)
        estimates[mode] = result_diff_dg.total_docs

    # compute absolute differences
    diffs = {m: abs(estimates[m] - total_diff_docs) for m in estimates}
    min_diff = min(diffs.values())

    # find all modes that achieved the minimum distance
    tied_modes = [m for m, diff in diffs.items() if diff == min_diff]

    if len(tied_modes) == 1:
        # clear single winner
        stats[tied_modes[0]] += 1
    else:
        # record tie, but no win awarded
        tie_key = " & ".join(sorted(tied_modes))
        tie_stats[tie_key] = tie_stats.get(tie_key, 0) + 1


# --- summarize results ---
print("\n=== RESULTS AFTER", num_iterations, "RUNS ===")
for mode, count in stats.items():
    print(f"{mode:12s}: {count} unique wins")

print("\n=== TIES ===")
if tie_stats:
    for tie_combo, count in sorted(tie_stats.items(), key=lambda x: -x[1]):
        print(f"{tie_combo:25s}: {count} times")
else:
    print("No ties occurred.")
# Out:
# === RESULTS AFTER 1000 RUNS ===
# lower_bound : 4 unique wins
# upper_bound : 551 unique wins
# mid         : 90 unique wins
#
# === TIES ===
# mid & upper_bound        : 285 times
# lower_bound & mid & upper_bound: 62 times
# lower_bound & mid        : 8 times

# %%
# Second larger test where dg1 is size 5-15 (random from docs 1-40), and dg2 is size 5-15 (random from docs 1-40)
# This tests essentially what happens when the dgs are ~ 12.5% - 37.5% the same
import random

random.seed(10)  

def make_hashable(value):
    if isinstance(value, dict):
        return frozenset((k, make_hashable(v)) for k, v in value.items())
    elif isinstance(value, list):
        return tuple(make_hashable(v) for v in value)
    else:
        return value

# since doc1–doc40 are already defined
all_docs = [globals()[f"doc{i}"] for i in range(1, 41)]

# tracking
stats = {"lower_bound": 0, "upper_bound": 0, "mid": 0}
tie_stats = {} 

num_iterations = 1000

for i in range(num_iterations):
    
    n1 = random.randint(5, 15)
    n2 = random.randint(5, 15)
    dg1_list = random.sample(all_docs, k=n1)
    dg2_list = random.sample(all_docs, k=n2)

    # convert to hashable for accurate set difference
    set1 = {make_hashable(d) for d in dg1_list}
    set2 = {make_hashable(d) for d in dg2_list}
    total_diff_docs = len(set1 - set2)

    # compute all three modes
    estimates = {}
    for mode in ["lower_bound", "upper_bound", "mid"]:
        dg_1 = DataGuidePath()
        dg_1.insert_document(dg1_list)
        dg_2 = DataGuidePath()
        dg_2.insert_document(dg2_list)
        result_diff_dg = dg_1.difference_beta(dg_2, mode=mode)
        estimates[mode] = result_diff_dg.total_docs

    # compute absolute differences
    diffs = {m: abs(estimates[m] - total_diff_docs) for m in estimates}
    min_diff = min(diffs.values())

    # find all modes that achieved the minimum distance
    tied_modes = [m for m, diff in diffs.items() if diff == min_diff]

    if len(tied_modes) == 1:
        # clear single winner
        stats[tied_modes[0]] += 1
    else:
        # record tie, but no win awarded
        tie_key = " & ".join(sorted(tied_modes))
        tie_stats[tie_key] = tie_stats.get(tie_key, 0) + 1


# --- summarize results ---
print("\n=== RESULTS AFTER", num_iterations, "RUNS ===")
for mode, count in stats.items():
    print(f"{mode:12s}: {count} unique wins")

print("\n=== TIES ===")
if tie_stats:
    for tie_combo, count in sorted(tie_stats.items(), key=lambda x: -x[1]):
        print(f"{tie_combo:25s}: {count} times")
else:
    print("No ties occurred.")
# Out:
# === RESULTS AFTER 1000 RUNS ===
# lower_bound : 8 unique wins
# upper_bound : 474 unique wins
# mid         : 251 unique wins
#
# === TIES ===
# mid & upper_bound        : 190 times
# lower_bound & mid & upper_bound: 70 times
# lower_bound & mid        : 7 times

# %%
# Third larger test where dg1 is size 20-25 (random from docs 1-40), and dg2 is size 20-25 (random from docs 1-40)
# This tests what happens when the dgs are about half the same
import random

random.seed(10)  

def make_hashable(value):
    if isinstance(value, dict):
        return frozenset((k, make_hashable(v)) for k, v in value.items())
    elif isinstance(value, list):
        return tuple(make_hashable(v) for v in value)
    else:
        return value

# since doc1–doc40 are already defined
all_docs = [globals()[f"doc{i}"] for i in range(1, 41)]

# tracking
stats = {"lower_bound": 0, "upper_bound": 0, "mid": 0}
tie_stats = {} 

num_iterations = 1000

for i in range(num_iterations):
    
    n1 = random.randint(20, 25)
    n2 = random.randint(20, 25)
    dg1_list = random.sample(all_docs, k=n1)
    dg2_list = random.sample(all_docs, k=n2)

    # convert to hashable for accurate set difference
    set1 = {make_hashable(d) for d in dg1_list}
    set2 = {make_hashable(d) for d in dg2_list}
    total_diff_docs = len(set1 - set2)

    # compute all three modes
    estimates = {}
    for mode in ["lower_bound", "upper_bound", "mid"]:
        dg_1 = DataGuidePath()
        dg_1.insert_document(dg1_list)
        dg_2 = DataGuidePath()
        dg_2.insert_document(dg2_list)
        result_diff_dg = dg_1.difference_beta(dg_2, mode=mode)
        estimates[mode] = result_diff_dg.total_docs

    # compute absolute differences
    diffs = {m: abs(estimates[m] - total_diff_docs) for m in estimates}
    min_diff = min(diffs.values())

    # find all modes that achieved the minimum distance
    tied_modes = [m for m, diff in diffs.items() if diff == min_diff]

    if len(tied_modes) == 1:
        # clear single winner
        stats[tied_modes[0]] += 1
    else:
        # record tie, but no win awarded
        tie_key = " & ".join(sorted(tied_modes))
        tie_stats[tie_key] = tie_stats.get(tie_key, 0) + 1


# --- summarize results ---
print("\n=== RESULTS AFTER", num_iterations, "RUNS ===")
for mode, count in stats.items():
    print(f"{mode:12s}: {count} unique wins")

print("\n=== TIES ===")
if tie_stats:
    for tie_combo, count in sorted(tie_stats.items(), key=lambda x: -x[1]):
        print(f"{tie_combo:25s}: {count} times")
else:
    print("No ties occurred.")
# Out:
# === RESULTS AFTER 1000 RUNS ===
# lower_bound : 1 unique wins
# upper_bound : 693 unique wins
# mid         : 205 unique wins
#
# === TIES ===
# mid & upper_bound        : 86 times
# lower_bound & mid & upper_bound: 14 times
# lower_bound & mid        : 1 times

# %%
# Fourth larger test where dg1 is size 20-40 (random from docs 1-40), and dg2 is size 20-40 (random from docs 1-40)
# This tests what happens when the dgs are over half the same
import random

random.seed(10)  

def make_hashable(value):
    if isinstance(value, dict):
        return frozenset((k, make_hashable(v)) for k, v in value.items())
    elif isinstance(value, list):
        return tuple(make_hashable(v) for v in value)
    else:
        return value

# since doc1–doc40 are already defined
all_docs = [globals()[f"doc{i}"] for i in range(1, 41)]

# tracking
stats = {"lower_bound": 0, "upper_bound": 0, "mid": 0}
tie_stats = {} 

num_iterations = 1000

for i in range(num_iterations):
    
    n1 = random.randint(20, 40)
    n2 = random.randint(20, 40)
    dg1_list = random.sample(all_docs, k=n1)
    dg2_list = random.sample(all_docs, k=n2)

    # convert to hashable for accurate set difference
    set1 = {make_hashable(d) for d in dg1_list}
    set2 = {make_hashable(d) for d in dg2_list}
    total_diff_docs = len(set1 - set2)

    # compute all three modes
    estimates = {}
    for mode in ["lower_bound", "upper_bound", "mid"]:
        dg_1 = DataGuidePath()
        dg_1.insert_document(dg1_list)
        dg_2 = DataGuidePath()
        dg_2.insert_document(dg2_list)
        result_diff_dg = dg_1.difference_beta(dg_2, mode=mode)
        estimates[mode] = result_diff_dg.total_docs

    # compute absolute differences
    diffs = {m: abs(estimates[m] - total_diff_docs) for m in estimates}
    min_diff = min(diffs.values())

    # find all modes that achieved the minimum distance
    tied_modes = [m for m, diff in diffs.items() if diff == min_diff]

    if len(tied_modes) == 1:
        # clear single winner
        stats[tied_modes[0]] += 1
    else:
        # record tie, but no win awarded
        tie_key = " & ".join(sorted(tied_modes))
        tie_stats[tie_key] = tie_stats.get(tie_key, 0) + 1


# --- summarize results ---
print("\n=== RESULTS AFTER", num_iterations, "RUNS ===")
for mode, count in stats.items():
    print(f"{mode:12s}: {count} unique wins")

print("\n=== TIES ===")
if tie_stats:
    for tie_combo, count in sorted(tie_stats.items(), key=lambda x: -x[1]):
        print(f"{tie_combo:25s}: {count} times")
else:
    print("No ties occurred.")
# Out:
# === RESULTS AFTER 1000 RUNS ===
# lower_bound : 398 unique wins
# upper_bound : 226 unique wins
# mid         : 139 unique wins
#
# === TIES ===
# lower_bound & mid & upper_bound: 119 times
# mid & upper_bound        : 103 times
# lower_bound & mid        : 15 times

# %%
# Fifth larger test where dg1 is size 35-40 (random from docs 1-40), and dg2 is size 35-40 (random from docs 1-40)
# This tests essentialy when two dgs share most or all the documents
import random

random.seed(10)  

def make_hashable(value):
    if isinstance(value, dict):
        return frozenset((k, make_hashable(v)) for k, v in value.items())
    elif isinstance(value, list):
        return tuple(make_hashable(v) for v in value)
    else:
        return value

# since doc1–doc40 are already defined
all_docs = [globals()[f"doc{i}"] for i in range(1, 41)]

# tracking
stats = {"lower_bound": 0, "upper_bound": 0, "mid": 0}
tie_stats = {} 

num_iterations = 1000

for i in range(num_iterations):
    
    n1 = random.randint(35, 40)
    n2 = random.randint(35, 40)
    dg1_list = random.sample(all_docs, k=n1)
    dg2_list = random.sample(all_docs, k=n2)

    # convert to hashable for accurate set difference
    set1 = {make_hashable(d) for d in dg1_list}
    set2 = {make_hashable(d) for d in dg2_list}
    total_diff_docs = len(set1 - set2)

    # compute all three modes
    estimates = {}
    for mode in ["lower_bound", "upper_bound", "mid"]:
        dg_1 = DataGuidePath()
        dg_1.insert_document(dg1_list)
        dg_2 = DataGuidePath()
        dg_2.insert_document(dg2_list)
        result_diff_dg = dg_1.difference_beta(dg_2, mode=mode)
        estimates[mode] = result_diff_dg.total_docs

    # compute absolute differences
    diffs = {m: abs(estimates[m] - total_diff_docs) for m in estimates}
    min_diff = min(diffs.values())

    # find all modes that achieved the minimum distance
    tied_modes = [m for m, diff in diffs.items() if diff == min_diff]

    if len(tied_modes) == 1:
        # clear single winner
        stats[tied_modes[0]] += 1
    else:
        # record tie, but no win awarded
        tie_key = " & ".join(sorted(tied_modes))
        tie_stats[tie_key] = tie_stats.get(tie_key, 0) + 1


# --- summarize results ---
print("\n=== RESULTS AFTER", num_iterations, "RUNS ===")
for mode, count in stats.items():
    print(f"{mode:12s}: {count} unique wins")

print("\n=== TIES ===")
if tie_stats:
    for tie_combo, count in sorted(tie_stats.items(), key=lambda x: -x[1]):
        print(f"{tie_combo:25s}: {count} times")
else:
    print("No ties occurred.")
# Out:
# === RESULTS AFTER 1000 RUNS ===
# lower_bound : 532 unique wins
# upper_bound : 49 unique wins
# mid         : 106 unique wins
#
# === TIES ===
# lower_bound & mid & upper_bound: 164 times
# mid & upper_bound        : 92 times
# lower_bound & mid        : 57 times

# %%
# Sixth larger test where dg1 is size 5-40 (random from docs 1-40), and dg2 is size 5-40 (random from docs 1-40)
# This tests essentialy when two dgs size difference is unpredictable 
import random

random.seed(10)  

def make_hashable(value):
    if isinstance(value, dict):
        return frozenset((k, make_hashable(v)) for k, v in value.items())
    elif isinstance(value, list):
        return tuple(make_hashable(v) for v in value)
    else:
        return value

# since doc1–doc40 are already defined
all_docs = [globals()[f"doc{i}"] for i in range(1, 41)]

# tracking
stats = {"lower_bound": 0, "upper_bound": 0, "mid": 0}
tie_stats = {} 

num_iterations = 1000

for i in range(num_iterations):
    
    n1 = random.randint(5, 40)
    n2 = random.randint(5, 40)
    dg1_list = random.sample(all_docs, k=n1)
    dg2_list = random.sample(all_docs, k=n2)

    # convert to hashable for accurate set difference
    set1 = {make_hashable(d) for d in dg1_list}
    set2 = {make_hashable(d) for d in dg2_list}
    total_diff_docs = len(set1 - set2)

    # compute all three modes
    estimates = {}
    for mode in ["lower_bound", "upper_bound", "mid"]:
        dg_1 = DataGuidePath()
        dg_1.insert_document(dg1_list)
        dg_2 = DataGuidePath()
        dg_2.insert_document(dg2_list)
        result_diff_dg = dg_1.difference_beta(dg_2, mode=mode)
        estimates[mode] = result_diff_dg.total_docs

    # compute absolute differences
    diffs = {m: abs(estimates[m] - total_diff_docs) for m in estimates}
    min_diff = min(diffs.values())

    # find all modes that achieved the minimum distance
    tied_modes = [m for m, diff in diffs.items() if diff == min_diff]

    if len(tied_modes) == 1:
        # clear single winner
        stats[tied_modes[0]] += 1
    else:
        # record tie, but no win awarded
        tie_key = " & ".join(sorted(tied_modes))
        tie_stats[tie_key] = tie_stats.get(tie_key, 0) + 1


# --- summarize results ---
print("\n=== RESULTS AFTER", num_iterations, "RUNS ===")
for mode, count in stats.items():
    print(f"{mode:12s}: {count} unique wins")

print("\n=== TIES ===")
if tie_stats:
    for tie_combo, count in sorted(tie_stats.items(), key=lambda x: -x[1]):
        print(f"{tie_combo:25s}: {count} times")
else:
    print("No ties occurred.")
# Out:
# === RESULTS AFTER 1000 RUNS ===
# lower_bound : 382 unique wins
# upper_bound : 190 unique wins
# mid         : 207 unique wins
#
# === TIES ===
# lower_bound & mid & upper_bound: 99 times
# mid & upper_bound        : 87 times
# lower_bound & mid        : 35 times

# %%
# COMPLETELY DISJOINT COLLECTION TESTS
# This collection will be used to compare to the above doc1-doc40 of document

doc41 = { "f_name": "John", "l_name": "Smith", "age": 25}
doc42 = { "f_name": "Edward", "l_name": "Gomez", "age": 28, "sport": "soccer"} 
doc43 = { "f_name": "Timothy", "l_name": "White", "age": 35, "sport": "tennis"} 
doc44 = { "f_name": "Amanda", "age": 21, "sport": "tennis", "hobbies":["knitting", "painting"]} 
doc45 = { "f_name": "Gregory", "l_name": "Khan", "age": 40, "sport": "tennis"} 
doc46 = { "f_name": "Kelly", "l_name": "Li", "age": 30, "hobbies":["knitting", "painting", "mechanic"], "employed": True} 
doc47 = { "f_name": "Robert", "l_name": "Jones", "age": 44, "sport": "basketball" }
doc48 = { "f_name": "Sarah", "l_name": "White", "age": 29, "sport": "swimming" }
doc49 = { "f_name": "Michael", "l_name": "Lee", "age": 51, "sport": "golf" }
doc50 = { "f_name": "Jennifer", "age": 22, "sport": "tennis" }
doc51 = { "f_name": "Paul", "l_name": "Adams", "age": 60, "sport": "chess" }
doc52 = { "f_name": "Victoria", "l_name": "Smith", "age": 33, "sport": "running" }
doc53 = { "f_name": "Alex", "l_name": "Chen", "age": 25, "hobbies": ["reading"] }
doc54 = { "f_name": "Ryan", "age": 31, "sport": "soccer", "hobbies": ["gaming", "hiking"], "employed": False }
doc55 = { "f_name": "Emily", "l_name": "Carter", "age": 24.5, "sport": "baseball" }
doc56 = { "f_name": "Thomas", "age": 55, "sport": "golf", "hobbies": ["fishing", "boating"], "employed": True }
doc57 = { "f_name": "Maria", "l_name": "Silva", "age": 38, "employed": True }
doc58 = { "f_name": "Daniel", "age": 42, "sport": "swimming", "hobbies": ["diving"] }
doc59 = { "f_name": "Jessica", "age": 27, "sport": "running", "employed": False }
doc60 = { "f_name": "William", "l_name": "Brown", "age": 49, "hobbies": ["baking", "hiking"], "employed": True }
doc61 = { "f_name": "Sophia",  "age": 30, "employed": True, "department": "Marketing" }
doc62 = { "f_name": "James", "age": 39, "employed": True, "is_manager": False }
doc63 = { "f_name": "Olivia", "l_name": "Garcia", "age": 41, "sport": "basketball", "hobbies": ["coaching"], "employed": True, "salary": 95000.00 }
doc64 = { "f_name": "Ethan", "l_name": "Lopez", "age": 23, "employed": False, "start_date": "2023-08-01" }
doc65 = { "f_name": "Ava", "l_name": "Kim", "age": 36, "sport": "tennis", "employed": True, "office_location": "HQ" }
doc66 = { "l_name": "Hernandez", "age": 52, "sport": "golf", "employed": False, "is_manager": True }
doc67 = { "f_name": "Mia", "l_name": "Wang", "age": 26, "hobbies": ["traveling"], "travel_status": "active" }
doc68 = { "f_name": "Lucas", "l_name": "Scott", "age": 47, "sport": "soccer", "hobbies": ["refereeing"], "employed": True, "salary": 110000 }
doc69 = { "f_name": "Abigail", "l_name": "Martinez", "age": 20, "employed": False, "student": True }
doc70 = { "l_name": "Perez", "age": 34, "sport": "running", "employed": True, "department": "Finance" }
doc71 = { "f_name": "Charlotte", "age": 28, "hobbies": ["photography"], "employed": True, "address": { "street": "123 Main St", "city": "Boulder" } }
doc72 = { "f_name": "Henry", "l_name": "Taylor", "age": 58, "hobbies": ["reading", "history"], "certifications": ["PMP", "CSM"] }
doc73 = { "f_name": "Amelia",  "age": 32, "sport": "swimming", "employed": False, "goals": ["medal", "PB"] }
doc74 = { "f_name": "Mason", "age": 45, "sport": "baseball", "hobbies": ["fantasy league"], "employed": True, "perormance_rating": 0.85 }
doc75 = { "f_name": "Evelyn",  "age": 63, "hobbies": ["gardening", "yoga"], "employed": False, "retirement_age": 65 }
doc76 = { "f_name": "Ben", "age": 29, "employed": True, "is_full_time": True }
doc77 = { "f_name": "Harper", "l_name": "King", "age": 40, "employed": True, "pets": ["dog", "cat", "fish"] }
doc78 = { "f_name": "Finn", "l_name": "Wright", "age": 37, "hobbies": ["coding", "data science"], "employed": True, "skills": ["Python", "SQL", "Cloud"] }
doc79 = { "f_name": "Luna",  "age": 21, "sport": "tennis", "hobbies": ["art", "music"], "employed": False, "education": "College" }
doc80 = { "f_name": "Carter", "l_name": "Gonzalez", "age": 50, "sport": "golf", "employed": True, "office_number": 402 }

# %%
# Comparing C1 (Collection 1) against the new C2 (Collection 2) above
# First test collection of 5 v 40

import random

random.seed(10)  

def make_hashable(obj):
    if isinstance(obj, dict):
        # convert dict -> frozenset of (key, value)
        return frozenset((k, make_hashable(v)) for k, v in obj.items())
    elif isinstance(obj, (list, tuple, set)):
        # convert list/set/tuple -> tuple of hashable elements
        return tuple(make_hashable(v) for v in obj)
    else:
        # base case: already hashable (str, int, float, bool, None)
        return obj


# since doc1–doc40 are already defined
c1 = [globals()[f"doc{i}"] for i in range(1, 41)]
c2 = [globals()[f"doc{i}"] for i in range(41, 81)]

# tracking
stats = {"lower_bound": 0, "upper_bound": 0, "mid": 0}
tie_stats = {} 

num_iterations = 1000

for i in range(num_iterations):
    
    dg1_list = random.sample(c1, k=5)
    dg2_list = random.sample(c2, k=40)

    # convert to hashable for accurate set difference
    set1 = {make_hashable(d) for d in dg1_list}
    set2 = {make_hashable(d) for d in dg2_list}
    total_diff_docs = len(set1 - set2)

    # compute all three modes
    estimates = {}
    for mode in ["lower_bound", "upper_bound", "mid"]:
        dg_1 = DataGuidePath()
        dg_1.insert_document(dg1_list)
        dg_2 = DataGuidePath()
        dg_2.insert_document(dg2_list)
        result_diff_dg = dg_1.difference_beta(dg_2, mode=mode)
        estimates[mode] = result_diff_dg.total_docs

    # compute absolute differences
    diffs = {m: abs(estimates[m] - total_diff_docs) for m in estimates}
    min_diff = min(diffs.values())

    # find all modes that achieved the minimum distance
    tied_modes = [m for m, diff in diffs.items() if diff == min_diff]

    if len(tied_modes) == 1:
        # clear single winner
        stats[tied_modes[0]] += 1
    else:
        # record tie, but no win awarded
        tie_key = " & ".join(sorted(tied_modes))
        tie_stats[tie_key] = tie_stats.get(tie_key, 0) + 1


# --- summarize results ---
print("\n=== RESULTS AFTER", num_iterations, "RUNS ===")
for mode, count in stats.items():
    print(f"{mode:12s}: {count} unique wins")

print("\n=== TIES ===")
if tie_stats:
    for tie_combo, count in sorted(tie_stats.items(), key=lambda x: -x[1]):
        print(f"{tie_combo:25s}: {count} times")
else:
    print("No ties occurred.")
# Out:
# === RESULTS AFTER 1000 RUNS ===
# lower_bound : 112 unique wins
# upper_bound : 0 unique wins
# mid         : 16 unique wins
#
# === TIES ===
# lower_bound & mid & upper_bound: 765 times
# mid & upper_bound        : 107 times

# %%
# Second test, calling in reverse order so it will be 40 v 5
import random

random.seed(10)  

def make_hashable(obj):
    if isinstance(obj, dict):
        # convert dict -> frozenset of (key, value)
        return frozenset((k, make_hashable(v)) for k, v in obj.items())
    elif isinstance(obj, (list, tuple, set)):
        # convert list/set/tuple -> tuple of hashable elements
        return tuple(make_hashable(v) for v in obj)
    else:
        # base case: already hashable (str, int, float, bool, None)
        return obj


# since doc1–doc40 are already defined
c1 = [globals()[f"doc{i}"] for i in range(1, 41)]
c2 = [globals()[f"doc{i}"] for i in range(41, 81)]

# tracking
stats = {"lower_bound": 0, "upper_bound": 0, "mid": 0}
tie_stats = {} 

num_iterations = 1000

for i in range(num_iterations):
    
    dg1_list = random.sample(c1, k=5)
    dg2_list = random.sample(c2, k=40)

    # convert to hashable for accurate set difference
    set1 = {make_hashable(d) for d in dg1_list}
    set2 = {make_hashable(d) for d in dg2_list}
    total_diff_docs = len(set2 - set1)

    # compute all three modes
    estimates = {}
    for mode in ["lower_bound", "upper_bound", "mid"]:
        dg_1 = DataGuidePath()
        dg_1.insert_document(dg1_list)
        dg_2 = DataGuidePath()
        dg_2.insert_document(dg2_list)
        result_diff_dg = dg_2.difference_beta(dg_1, mode=mode)
        estimates[mode] = result_diff_dg.total_docs

    # compute absolute differences
    diffs = {m: abs(estimates[m] - total_diff_docs) for m in estimates}
    min_diff = min(diffs.values())

    # find all modes that achieved the minimum distance
    tied_modes = [m for m, diff in diffs.items() if diff == min_diff]

    if len(tied_modes) == 1:
        # clear single winner
        stats[tied_modes[0]] += 1
    else:
        # record tie, but no win awarded
        tie_key = " & ".join(sorted(tied_modes))
        tie_stats[tie_key] = tie_stats.get(tie_key, 0) + 1


# --- summarize results ---
print("\n=== RESULTS AFTER", num_iterations, "RUNS ===")
for mode, count in stats.items():
    print(f"{mode:12s}: {count} unique wins")

print("\n=== TIES ===")
if tie_stats:
    for tie_combo, count in sorted(tie_stats.items(), key=lambda x: -x[1]):
        print(f"{tie_combo:25s}: {count} times")
else:
    print("No ties occurred.")
# Out:
# === RESULTS AFTER 1000 RUNS ===
# lower_bound : 0 unique wins
# upper_bound : 109 unique wins
# mid         : 126 unique wins
#
# === TIES ===
# mid & upper_bound        : 765 times

# %%
# Sanity check for test above, running one iteration
import random

random.seed(10)  

def make_hashable(obj):
    if isinstance(obj, dict):
        # convert dict -> frozenset of (key, value)
        return frozenset((k, make_hashable(v)) for k, v in obj.items())
    elif isinstance(obj, (list, tuple, set)):
        # convert list/set/tuple -> tuple of hashable elements
        return tuple(make_hashable(v) for v in obj)
    else:
        # base case: already hashable (str, int, float, bool, None)
        return obj

# since doc1–doc40 are already defined
c1 = [globals()[f"doc{i}"] for i in range(1, 41)]
c2 = [globals()[f"doc{i}"] for i in range(41, 81)]

# n1 = random.randint(20, 25)
n1=5
# n2 = random.randint(20, 25)
n2=40
dg1_list = random.sample(c1, k=n1)
dg2_list = random.sample(c2, k=n2)



dg1_list = random.sample(c1, k=5)
dg2_list = random.sample(c2, k=40)

# convert to hashable for accurate set difference
set1 = {make_hashable(d) for d in dg1_list}
set2 = {make_hashable(d) for d in dg2_list}
total_diff_docs = len(set2 - set1)
print("total_diff_docs: " + str(total_diff_docs))
# compute all three modes
estimates = {}
for mode in ["lower_bound", "upper_bound", "mid"]:
    dg_1 = DataGuidePath()
    dg_1.insert_document(dg1_list)
    dg_2 = DataGuidePath()
    dg_2.insert_document(dg2_list)
    result_diff_dg = dg_2.difference_beta(dg_1, mode=mode)
    estimates[mode] = result_diff_dg.total_docs
    print(mode + " = " + str(result_diff_dg.total_docs))
# Out:
# total_diff_docs: 40
# lower_bound = 39
# upper_bound = 40
# mid = 40

# %%
# Third test, comparing c1 with 20-25 docs and c2 with 20-25 docs
# This compares testing to disjoint collections with about the same number of documents

import random
random.seed(10)  

def make_hashable(obj):
    if isinstance(obj, dict):
        # convert dict -> frozenset of (key, value)
        return frozenset((k, make_hashable(v)) for k, v in obj.items())
    elif isinstance(obj, (list, tuple, set)):
        # convert list/set/tuple -> tuple of hashable elements
        return tuple(make_hashable(v) for v in obj)
    else:
        # base case: already hashable (str, int, float, bool, None)
        return obj


# since doc1–doc40 are already defined
c1 = [globals()[f"doc{i}"] for i in range(1, 41)]
c2 = [globals()[f"doc{i}"] for i in range(41, 81)]

# tracking
stats = {"lower_bound": 0, "upper_bound": 0, "mid": 0}
tie_stats = {} 

num_iterations = 1000

for i in range(num_iterations):
    
    n1 = random.randint(20, 25)
    n2 = random.randint(20, 25)
    dg1_list = random.sample(c1, k=n1)
    dg2_list = random.sample(c2, k=n2)

    # convert to hashable for accurate set difference
    set1 = {make_hashable(d) for d in dg1_list}
    set2 = {make_hashable(d) for d in dg2_list}
    total_diff_docs = len(set2 - set1)

    # compute all three modes
    estimates = {}
    for mode in ["lower_bound", "upper_bound", "mid"]:
        dg_1 = DataGuidePath()
        dg_1.insert_document(dg1_list)
        dg_2 = DataGuidePath()
        dg_2.insert_document(dg2_list)
        result_diff_dg = dg_2.difference_beta(dg_1, mode=mode)
        estimates[mode] = result_diff_dg.total_docs

    # compute absolute differences
    diffs = {m: abs(estimates[m] - total_diff_docs) for m in estimates}
    min_diff = min(diffs.values())

    # find all modes that achieved the minimum distance
    tied_modes = [m for m, diff in diffs.items() if diff == min_diff]

    if len(tied_modes) == 1:
        # clear single winner
        stats[tied_modes[0]] += 1
    else:
        # record tie, but no win awarded
        tie_key = " & ".join(sorted(tied_modes))
        tie_stats[tie_key] = tie_stats.get(tie_key, 0) + 1


# --- summarize results ---
print("\n=== RESULTS AFTER", num_iterations, "RUNS ===")
for mode, count in stats.items():
    print(f"{mode:12s}: {count} unique wins")

print("\n=== TIES ===")
if tie_stats:
    for tie_combo, count in sorted(tie_stats.items(), key=lambda x: -x[1]):
        print(f"{tie_combo:25s}: {count} times")
else:
    print("No ties occurred.")
# Out:
# === RESULTS AFTER 1000 RUNS ===
# lower_bound : 69 unique wins
# upper_bound : 319 unique wins
# mid         : 248 unique wins
#
# === TIES ===
# mid & upper_bound        : 270 times
# lower_bound & mid & upper_bound: 94 times

# %%
# Forth test, comparing c1 with 20 docs and c2 with 20 docs
# This compares testing to disjoint collections with about
# the same number of documents

import random

random.seed(10)  

def make_hashable(obj):
    if isinstance(obj, dict):
        # convert dict -> frozenset of (key, value)
        return frozenset((k, make_hashable(v)) for k, v in obj.items())
    elif isinstance(obj, (list, tuple, set)):
        # convert list/set/tuple -> tuple of hashable elements
        return tuple(make_hashable(v) for v in obj)
    else:
        # base case: already hashable (str, int, float, bool, None)
        return obj


# since doc1–doc40 are already defined
c1 = [globals()[f"doc{i}"] for i in range(1, 41)]
c2 = [globals()[f"doc{i}"] for i in range(41, 81)]

# tracking
stats = {"lower_bound": 0, "upper_bound": 0, "mid": 0}
tie_stats = {} 

num_iterations = 1000

for i in range(num_iterations):
    
    # n1 = random.randint(20, 25)
    n1=20
    # n2 = random.randint(20, 25)
    n2=20
    dg1_list = random.sample(c1, k=n1)
    dg2_list = random.sample(c2, k=n2)

    # convert to hashable for accurate set difference
    set1 = {make_hashable(d) for d in dg1_list}
    set2 = {make_hashable(d) for d in dg2_list}
    total_diff_docs = len(set2 - set1)

    # compute all three modes
    estimates = {}
    for mode in ["lower_bound", "upper_bound", "mid"]:
        dg_1 = DataGuidePath()
        dg_1.insert_document(dg1_list)
        dg_2 = DataGuidePath()
        dg_2.insert_document(dg2_list)
        result_diff_dg = dg_2.difference_beta(dg_1, mode=mode)
        estimates[mode] = result_diff_dg.total_docs

    # compute absolute differences
    diffs = {m: abs(estimates[m] - total_diff_docs) for m in estimates}
    min_diff = min(diffs.values())

    # find all modes that achieved the minimum distance
    tied_modes = [m for m, diff in diffs.items() if diff == min_diff]

    if len(tied_modes) == 1:
        # clear single winner
        stats[tied_modes[0]] += 1
    else:
        # record tie, but no win awarded
        tie_key = " & ".join(sorted(tied_modes))
        tie_stats[tie_key] = tie_stats.get(tie_key, 0) + 1


# --- summarize results ---
print("\n=== RESULTS AFTER", num_iterations, "RUNS ===")
for mode, count in stats.items():
    print(f"{mode:12s}: {count} unique wins")

print("\n=== TIES ===")
if tie_stats:
    for tie_combo, count in sorted(tie_stats.items(), key=lambda x: -x[1]):
        print(f"{tie_combo:25s}: {count} times")
else:
    print("No ties occurred.")
# Out:
# === RESULTS AFTER 1000 RUNS ===
# lower_bound : 82 unique wins
# upper_bound : 287 unique wins
# mid         : 164 unique wins
#
# === TIES ===
# mid & upper_bound        : 330 times
# lower_bound & mid & upper_bound: 137 times

# %%
# Sanity check for test above
# Running just one iteration to see output

import random

random.seed(10)  

def make_hashable(obj):
    if isinstance(obj, dict):
        # convert dict -> frozenset of (key, value)
        return frozenset((k, make_hashable(v)) for k, v in obj.items())
    elif isinstance(obj, (list, tuple, set)):
        # convert list/set/tuple -> tuple of hashable elements
        return tuple(make_hashable(v) for v in obj)
    else:
        # base case: already hashable (str, int, float, bool, None)
        return obj

# since doc1–doc40 are already defined
c1 = [globals()[f"doc{i}"] for i in range(1, 41)]
c2 = [globals()[f"doc{i}"] for i in range(41, 81)]

# n1 = random.randint(20, 25)
n1=20
# n2 = random.randint(20, 25)
n2=20
dg1_list = random.sample(c1, k=n1)
dg2_list = random.sample(c2, k=n2)


# convert to hashable for accurate set difference
set1 = {make_hashable(d) for d in dg1_list}
set2 = {make_hashable(d) for d in dg2_list}
total_diff_docs = len(set2 - set1)
print("total_diff_docs: " + str(total_diff_docs))
# compute all three modes
estimates = {}
for mode in ["lower_bound", "upper_bound", "mid"]:
    dg_1 = DataGuidePath()
    dg_1.insert_document(dg1_list)
    dg_2 = DataGuidePath()
    dg_2.insert_document(dg2_list)
    result_diff_dg = dg_2.difference_beta(dg_1, mode=mode)
    estimates[mode] = result_diff_dg.total_docs
    print(mode + " = " + str(result_diff_dg.total_docs))
# Out:
# total_diff_docs: 20
# lower_bound = 19
# upper_bound = 20
# mid = 20

# %%
# Fifth test, comparing c1 with 40 docs and c2 with 40 docs
# This compares testing to disjoint collections with about the same number of documents but slightly larger from 20-25doc to 40

import random

random.seed(10)  

def make_hashable(obj):
    if isinstance(obj, dict):
        # convert dict -> frozenset of (key, value)
        return frozenset((k, make_hashable(v)) for k, v in obj.items())
    elif isinstance(obj, (list, tuple, set)):
        # convert list/set/tuple -> tuple of hashable elements
        return tuple(make_hashable(v) for v in obj)
    else:
        # base case: already hashable (str, int, float, bool, None)
        return obj

# since doc1–doc40 are already defined
c1 = [globals()[f"doc{i}"] for i in range(1, 41)]
c2 = [globals()[f"doc{i}"] for i in range(41, 81)]

# tracking
stats = {"lower_bound": 0, "upper_bound": 0, "mid": 0}
tie_stats = {} 

num_iterations = 1000

for i in range(num_iterations):
    
    # n1 = random.randint(20, 25)
    n1=40
    # n2 = random.randint(20, 25)
    n2=40
    dg1_list = random.sample(c1, k=n1)
    dg2_list = random.sample(c2, k=n2)

    # convert to hashable for accurate set difference
    set1 = {make_hashable(d) for d in dg1_list}
    set2 = {make_hashable(d) for d in dg2_list}
    total_diff_docs = len(set2 - set1)

    # compute all three modes
    estimates = {}
    for mode in ["lower_bound", "upper_bound", "mid"]:
        dg_1 = DataGuidePath()
        dg_1.insert_document(dg1_list)
        dg_2 = DataGuidePath()
        dg_2.insert_document(dg2_list)
        result_diff_dg = dg_2.difference_beta(dg_1, mode=mode)
        estimates[mode] = result_diff_dg.total_docs

    # compute absolute differences
    diffs = {m: abs(estimates[m] - total_diff_docs) for m in estimates}
    min_diff = min(diffs.values())

    # find all modes that achieved the minimum distance
    tied_modes = [m for m, diff in diffs.items() if diff == min_diff]

    if len(tied_modes) == 1:
        # clear single winner
        stats[tied_modes[0]] += 1
    else:
        # record tie, but no win awarded
        tie_key = " & ".join(sorted(tied_modes))
        tie_stats[tie_key] = tie_stats.get(tie_key, 0) + 1


# --- summarize results ---
print("\n=== RESULTS AFTER", num_iterations, "RUNS ===")
for mode, count in stats.items():
    print(f"{mode:12s}: {count} unique wins")

print("\n=== TIES ===")
if tie_stats:
    for tie_combo, count in sorted(tie_stats.items(), key=lambda x: -x[1]):
        print(f"{tie_combo:25s}: {count} times")
else:
    print("No ties occurred.")
# Out:
# === RESULTS AFTER 1000 RUNS ===
# lower_bound : 0 unique wins
# upper_bound : 0 unique wins
# mid         : 1000 unique wins
#
# === TIES ===
# No ties occurred.

# %%
# Sanity check for test above
# Runnign just one iteration to see output

import random

random.seed(10)  

def make_hashable(obj):
    if isinstance(obj, dict):
        # convert dict -> frozenset of (key, value)
        return frozenset((k, make_hashable(v)) for k, v in obj.items())
    elif isinstance(obj, (list, tuple, set)):
        # convert list/set/tuple -> tuple of hashable elements
        return tuple(make_hashable(v) for v in obj)
    else:
        # base case: already hashable (str, int, float, bool, None)
        return obj

# since doc1–doc40 are already defined
c1 = [globals()[f"doc{i}"] for i in range(1, 41)]
c2 = [globals()[f"doc{i}"] for i in range(41, 81)]

# n1 = random.randint(20, 25)
n1=40
# n2 = random.randint(20, 25)
n2=40
dg1_list = random.sample(c1, k=n1)
dg2_list = random.sample(c2, k=n2)


# convert to hashable for accurate set difference
set1 = {make_hashable(d) for d in dg1_list}
set2 = {make_hashable(d) for d in dg2_list}
total_diff_docs = len(set2 - set1)
print("total_diff_docs: " + str(total_diff_docs))
# compute all three modes
estimates = {}
for mode in ["lower_bound", "upper_bound", "mid"]:
    dg_1 = DataGuidePath()
    dg_1.insert_document(dg1_list)
    dg_2 = DataGuidePath()
    dg_2.insert_document(dg2_list)
    result_diff_dg = dg_2.difference_beta(dg_1, mode=mode)
    estimates[mode] = result_diff_dg.total_docs
    print(mode + " = " + str(result_diff_dg.total_docs))

# Since the total diff docs is actually 39, upper_bound and mid are the closest
# Yet all are good estimates
# Out:
# total_diff_docs: 39
# lower_bound = 37
# upper_bound = 40
# mid = 39

# %%
# Sixth test, comparing c1 with 40 docs and c2 with 40 docs, but calling in reverse order
# This compares testing to disjoint collections with about the same number of documents 40docs

import random

random.seed(10)  

def make_hashable(obj):
    if isinstance(obj, dict):
        # convert dict -> frozenset of (key, value)
        return frozenset((k, make_hashable(v)) for k, v in obj.items())
    elif isinstance(obj, (list, tuple, set)):
        # convert list/set/tuple -> tuple of hashable elements
        return tuple(make_hashable(v) for v in obj)
    else:
        # base case: already hashable (str, int, float, bool, None)
        return obj


# since doc1–doc40 are already defined
c1 = [globals()[f"doc{i}"] for i in range(1, 41)]
c2 = [globals()[f"doc{i}"] for i in range(41, 81)]

# tracking
stats = {"lower_bound": 0, "upper_bound": 0, "mid": 0}
tie_stats = {} 

num_iterations = 1000

for i in range(num_iterations):
    
    # n1 = random.randint(20, 25)
    n1=40
    # n2 = random.randint(20, 25)
    n2=40
    dg1_list = random.sample(c1, k=n1)
    dg2_list = random.sample(c2, k=n2)

    # convert to hashable for accurate set difference
    set1 = {make_hashable(d) for d in dg1_list}
    set2 = {make_hashable(d) for d in dg2_list}
    total_diff_docs = len(set1 - set2)

    # compute all three modes
    estimates = {}
    for mode in ["lower_bound", "upper_bound", "mid"]:
        dg_1 = DataGuidePath()
        dg_1.insert_document(dg1_list)
        dg_2 = DataGuidePath()
        dg_2.insert_document(dg2_list)
        result_diff_dg = dg_1.difference_beta(dg_2, mode=mode)
        estimates[mode] = result_diff_dg.total_docs

    # compute absolute differences
    diffs = {m: abs(estimates[m] - total_diff_docs) for m in estimates}
    min_diff = min(diffs.values())

    # find all modes that achieved the minimum distance
    tied_modes = [m for m, diff in diffs.items() if diff == min_diff]

    if len(tied_modes) == 1:
        # clear single winner
        stats[tied_modes[0]] += 1
    else:
        # record tie, but no win awarded
        tie_key = " & ".join(sorted(tied_modes))
        tie_stats[tie_key] = tie_stats.get(tie_key, 0) + 1


# --- summarize results ---
print("\n=== RESULTS AFTER", num_iterations, "RUNS ===")
for mode, count in stats.items():
    print(f"{mode:12s}: {count} unique wins")

print("\n=== TIES ===")
if tie_stats:
    for tie_combo, count in sorted(tie_stats.items(), key=lambda x: -x[1]):
        print(f"{tie_combo:25s}: {count} times")
else:
    print("No ties occurred.")
# Out:
# === RESULTS AFTER 1000 RUNS ===
# lower_bound : 1000 unique wins
# upper_bound : 0 unique wins
# mid         : 0 unique wins
#
# === TIES ===
# No ties occurred.
