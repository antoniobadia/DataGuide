# %%
# Will need DataGuidePathClass.py for these test files
# This cell and next (data) cell need to be run for class and data usage

from DataGuidePathClass import DataGuidePath, Path # Importing needed classes

# %%
# Data that will be used across testing

data1 = {"a": 2, "b": {"c": 7, "d": 'bar', "e": 4}, "f": [1, 2, 3]}
data2 = {"a": 2, "b": {"c": 'bar'}, "g": 7}
data3 = [ # nesting documents for testing
    { "a": 1, "common": { "x": 10, "b": {"c": 7} }, "u1": "foo" },
    { "a": 2, "common": { "x": "twenty" }, "u2": "bar" },
    { "a": 3, "common": { "x": 30 } }
]
data4 = [ # second list of nested documents for testing
    { "a": 100, "common": { "x": 40 }, "v1": 3.14 },
    { "a": 200, "common": { "x": 20 }},
    { "a": 300, "common": { "x": "gamma" }, "v2": 2.71 }
]
data5 = {'a': 42, 'b': {'e': 99}, 'f': [{'l': 1}]}
data6 = {'a': 1, 'b': {'c': 'foo', 'd': 'bar', 'e': 4}, 'f': [{'k':"r"}, {"l": 2}, 3]}
data7 = {'a': 1, 'b': {'c': 'foo', 'd': 'bar', 'e': 4}, 'f': [1, 2, 3]}

# %%
# --- Testing Project function from here ---

# %%
# Start by creating a dataguide with one single document, and printing output
dg_one_doc = DataGuidePath()
dg_one_doc.insert_document(data1)
print("Original dataguide with one document:")
dg_one_doc.print_guide()
# Out:
# Original dataguide with one document:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 0}
# root.a: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.b: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 0}
# root.b.c: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.b.d: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.b.e: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.f: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 1}
# root.f.*: {'int': 3, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}

# %%
# Checking a simple path within dataguide, storing in a new dataguide, printing results
projected_1 = dg_one_doc.project('f.*.k')
print("Project path 'b' in dataguide with one document:")
projected_1.print_guide()
# Out:
# Project path 'b' in dataguide with one document:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 1}
# root.f: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.f.*: {'int': 3, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}

# %%
#Creating a dataguide with two documents
dg_two_doc = DataGuidePath()
dg_two_doc.insert_document([data1,data2])
#printing dataguide to confirm documents added
print("Original dataguide with two documents:")
dg_two_doc.print_guide()
# Out:
# Original dataguide with two documents:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 2, 'arr': 0}
# root.a: {'int': 2, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.b: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 2, 'arr': 0}
# root.b.c: {'int': 1, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.b.d: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.b.e: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.f: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 1}
# root.f.*: {'int': 3, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.g: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}

# %%
# Checking a simple path within dataguide with two documents
projected_2 = dg_two_doc.project('b')
print("Project path 'b' in dataguide with two documents:")
projected_2.print_guide()
# Out:
# Project path 'b' in dataguide with two documents:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 0}
# root.b: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.b.c: {'int': 1, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.b.d: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.b.e: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}

# %%
#Checking output if path does not exist
projected_3 = dg_two_doc.project('z') # z is not in doc1 or doc2 so no values should be in new dataguide
print("Project path 'z' in dataguide with two documents:")
projected_3.print_guide()
# Out:
# Project path 'z' in dataguide with two documents:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}

# %%
# Creating new dataguides for testing
d2_guide = DataGuidePath()
d2_guide.insert_document(data6)

# %%
#Showing data for reference of next step
print("d2_guide dataguide:")
d2_guide.print_guide() # This dataguide only contains one document
# Out:
# d2_guide dataguide:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 0}
# root.a: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.b: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 0}
# root.b.c: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.b.d: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.b.e: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.f: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 1}
# root.f.*: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 2, 'arr': 0}
# root.f.*.k: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.f.*.l: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}

# %%
# Checking for more complex paths within dataguide and printing new dataguide
projected_4 = d2_guide.project(['b.c', 'f.*.k'])
print("Dataguide projecting paths 'b.c' and 'f.*.k' ")
projected_4.print_guide()
# Out:
# Dataguide projecting paths 'b.c' and 'f.*.k'
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 1}
# root.b: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.b.c: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.f: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 0}
# root.f.*: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.f.*.k: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}

# %%
print("Estimated docs with all projected paths:", projected_4.total_docs) # original dataguide contained only one document so this is accurate
# Out:
# Estimated docs with all projected paths: 1

# %%
# Adding two more documents and then attempting same projection, to see if it works with multipls documents
d2_guide.insert_document([data1, data2])
# Showing data for reference of next step
print("d2_guide dataguide:")
d2_guide.print_guide()
# Out:
# d2_guide dataguide:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 3, 'arr': 0}
# root.a: {'int': 3, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.b: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 3, 'arr': 0}
# root.b.c: {'int': 1, 'str': 2, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.b.d: {'int': 0, 'str': 2, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.b.e: {'int': 2, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.f: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 2}
# root.f.*: {'int': 4, 'str': 0, 'float': 0, 'date': 0, 'obj': 2, 'arr': 0}
# root.f.*.k: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.f.*.l: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.g: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}

# %%
# Once again checking for more complex paths for dataguide with more docs
projected_5 = d2_guide.project(['b.c', 'f.*.k']) # all 3 docs have path b.c
print("Dataguide with 3 docs projecting paths 'b.c' and 'f.*.k' ")
projected_5.print_guide()
# Out:
# Dataguide with 3 docs projecting paths 'b.c' and 'f.*.k'
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 1}
# root.b: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.b.c: {'int': 1, 'str': 2, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.f: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 0}
# root.f.*: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.f.*.k: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}

# %%
print("Estimated docs with all projected paths:", projected_5.total_docs) 
# dataguide contained three documents so this is accurate as all 3 contained path 'b.c'
# Out:
# Estimated docs with all projected paths: 3

# %%
# Testing to see what if only one documnet has the projected path
projected_6 = d2_guide.project(['f.*.k']) # all 3 docs have path b.c
print("Dataguide with 3 docs projecting path'f.*.k' ")
projected_6.print_guide()
# Out:
# Dataguide with 3 docs projecting path'f.*.k'
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 1}
# root.f: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 0}
# root.f.*: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.f.*.k: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}

# %%
print("Estimated docs with all projected paths:", projected_6.total_docs) 
# dataguide contained three documents, but only one contained the path f.*.k so this accurately prints 1
# Out:
# Estimated docs with all projected paths: 1

# %%
# What if only some docs have the requested paths in a much larger collection
# Checking path b.c
dg_final_large = DataGuidePath()
dg_final_large.insert_document([data7, data6, data1, data2, data3, data4, data5])
# Printing the projected dataguide for reference
final_projected = dg_final_large.project(['b.c'])
final_projected.print_guide()
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 0}
# root.b: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.b.c: {'int': 1, 'str': 3, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}

# %%
print('Original dataguide without any projection for dg_final_large: ')
dg_final_large.print_guide()
# Out:
# Original dataguide without any projection for dg_final_large:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 11, 'arr': 0}
# root.a: {'int': 11, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.b: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 5, 'arr': 0}
# root.b.c: {'int': 1, 'str': 3, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.b.d: {'int': 0, 'str': 3, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.b.e: {'int': 4, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.f: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 4}
# root.f.*: {'int': 7, 'str': 0, 'float': 0, 'date': 0, 'obj': 3, 'arr': 0}
# root.f.*.k: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.f.*.l: {'int': 2, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.g: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.common: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 6, 'arr': 0}
# ...

# %%
# checking how many docs have the following paths 'b.c' in root, correctly outputs 4
print("Projected total_docs in dg_final_large:", final_projected.total_docs)
# Out:
# Projected total_docs in dg_final_large: 4

# %%
# Now testing paths ['b.c', 'f.*.k'] again, the count should be 5 because root contains 5
final_complex_projected_dg = dg_final_large.project(['b.c', 'f.*.k'])
print("Projected total_docs in dg_final_large:", final_complex_projected_dg.project(['b.c', 'f.*.k'])
.total_docs)
# Out:
# Projected total_docs in dg_final_large: 5

# %%
# Testing to see that max docs impacted will not be more than total docs:
# final_complex_projected_dg = dg_final_large.project(['b.c', 'f.*.k', 'f.*'])
print("Projected total_docs in dg_final_large:", dg_final_large.project(['b.c', 'f.*.k', 'a'])
.total_docs)
#Output is 7 which matches original docs inserted
# Out:
# Projected total_docs in dg_final_large: 11

# %%
# --- END OF Project Testing ---

# %%
# --- Test Nest / Group By function starting from here ---

# %%
# Side test
data_for_proj = [
{"id": 1, "name": "Alice", "city": "NYC"},
{"id": 2, "age": 30, "city": "LA"}
]
project_dg = DataGuidePath()
project_dg.insert_document(data_for_proj)
project_dg.print_guide()
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 2, 'arr': 0}
# root.id: {'int': 2, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.name: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.city: {'int': 0, 'str': 2, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.age: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}

# %%
transformed_guide = project_dg.nest_schema(
    grouping_paths=[Path("id")],
    nest_specs=[("details", [])]  
).print_guide()
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 2, 'arr': 1}
# root.details: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 1}
# root.details.*: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.details.*.age: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.details.*.city: {'int': 0, 'str': 2, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.details.*.name: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.id: {'int': 2, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}

# %%
transformed_guide = dg_one_doc.nest_schema(
    grouping_paths=[Path("id")],
    nest_specs=[("details", ["b.c", "b.d"])]  
).print_guide()
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 1}
# root.details: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 1}
# root.details.*: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 0}
# root.details.*.b: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.details.*.b.c: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.details.*.b.d: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}

# %%
# Testing for new Nest class, first creating dataguide with two documents
dg_simple_test = DataGuidePath()
dg_simple_test.insert_document(data7)
dg_simple_test.insert_document(data4)

# %%
print("Original dataguide for reference for nest function testing:")
dg_simple_test.print_guide()
# Out:
# Original dataguide for reference for nest function testing:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 4, 'arr': 0}
# root.a: {'int': 4, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.b: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 0}
# root.b.c: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.b.d: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.b.e: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.f: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 1}
# root.f.*: {'int': 3, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.common: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 3, 'arr': 0}
# root.common.x: {'int': 2, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.v1: {'int': 0, 'str': 0, 'float': 1, 'date': 0, 'obj': 0, 'arr': 0}
# root.v2: {'int': 0, 'str': 0, 'float': 1, 'date': 0, 'obj': 0, 'arr': 0}

# %%
#Testing on data 1 containing only one document
dg_one_doc.nest_schema(
    grouping_paths=[Path("b")]# Just a list of paths to be tested, output should only show these existing paths in dataguide, if they exist
).print_guide()
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 0}
# root.b: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.b.c: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.b.d: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.b.e: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}

# %%
# The new nest function accepts different parameters, arguement 1 case #1
# Testing a single path
dg_simple_test.nest_schema(
    grouping_paths=[Path("a")]# Just a list of paths to be tested, output should only show these existing paths in dataguide, if they exist
).print_guide() # From above we can see path 'a' exists only 1 so only 1 output, works as intended
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 0}
# root.a: {'int': 4, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}

# %%
# Testing total docs, same as above
testii = dg_simple_test.nest_schema(
    grouping_paths=[Path("a")]
)
testii.get_estimate_bounds()
# output should be 4,4,4
# Out:
# {'total_docs': 4, 'max_docs_est impacted': 0, 'min_docs_est impacted': 0}

# %%
# The new nest function accepts different parameters, arguement 1 case #1
dg_simple_test.nest_schema(
    grouping_paths=[Path("a"), Path("b.c")]# Just a list of paths to be tested, output should only show these existing paths in dataguide, if they exist
).print_guide()
# This also prints both paths as intended
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 0}
# root.a: {'int': 4, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.b: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.b.c: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}

# %%
# Testing total docs, same as above
testii = dg_simple_test.nest_schema(
    grouping_paths=[Path("a"), Path("b.c")]
)
testii.get_estimate_bounds()
# Correct output should be 4,4,4
# Out:
# {'total_docs': 4, 'max_docs_est impacted': 0, 'min_docs_est impacted': 0}

# %%
# Argument 3: Nesting with an empty path list
# Grouping by path 'b', and nesting all other non-grouping paths under 'e' as a list of documents
# This also tests both Path and string inputs
transformed_guide = dg_simple_test.nest_schema(
    grouping_paths=[Path("b")],
    nest_specs=[("e", [])]  # Empty list = nest everything except the grouping path
)

print("\nTransformed Data Guide:")
transformed_guide.print_guide()
# Out:
# Transformed Data Guide:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 2, 'arr': 1}
# root.b: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.b.c: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.b.d: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.b.e: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.e: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 1}
# root.e.*: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 1}
# root.e.*.a: {'int': 4, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.e.*.common: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.e.*.common.x: {'int': 2, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.e.*.f: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.e.*.f.*: {'int': 3, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# ...

# %%
# Testing total docs, using same as above
testii = dg_simple_test.nest_schema(
    grouping_paths=[Path("b")],
    nest_specs=[("e", [])] 
)
testii.get_estimate_bounds()
# Correct output should be 4,1,1 , originally there were 4 docs, out of the 4 only 1 contains path 'b' , so exact min and max is 1
# Out:
# {'total_docs': 4, 'max_docs_est impacted': 0, 'min_docs_est impacted': 0}

# %%
# Testing Arguement 3, case 1 with two paths, still empty list:
transformed_guide_two_paths = dg_simple_test.nest_schema(
    grouping_paths=[Path("a"), Path("b.c")],
    nest_specs=[("e", [])] # This is where non-grouping-keys will be moved
)

print("\nTransformed Data Guide:")
transformed_guide_two_paths.print_guide()
# Also works as expected
# Out:
# Transformed Data Guide:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 2, 'arr': 1}
# root.a: {'int': 4, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.b: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.b.c: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.e: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 1}
# root.e.*: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 1}
# root.e.*.b: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.e.*.b.d: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.e.*.b.e: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.e.*.common: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.e.*.common.x: {'int': 2, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.e.*.f: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# ...

# %%
# Testing total docs, using same as above
testii = dg_simple_test.nest_schema(
    grouping_paths=[Path("a"), Path("b.c")],
    nest_specs=[("e", [])]
)
testii.get_estimate_bounds()
# Correct output should be 4,4,4 , originally there were 4 docs, out of the 4 all 4 contains path 'a' , so exact min and max is 4
# Out:
# {'total_docs': 4, 'max_docs_est impacted': 0, 'min_docs_est impacted': 0}

# %%
# data1 = {"a": 2, "b": {"c": 7, "d": 'bar', "e": 4}, "f": [1, 2, 3]}
# data2 = {"a": 2, "b": {"c": 'bar'}, "g": 7}
# Testing doc estimate if one path in each document:
dg_simple_test2 = DataGuidePath()
dg_simple_test2.insert_document([data1, data2])
testii = dg_simple_test2.nest_schema(
    grouping_paths=[Path("b.d"), Path("g")],
    nest_specs=[("e", [])]
)
testii.get_estimate_bounds()
# The output should be 2 for max documents since one doc has path 'b.d' and the other has path 'g', 
# and min should be 1, because both paths could be in the same doc
# Out:
# {'total_docs': 2, 'max_docs_est impacted': 0, 'min_docs_est impacted': 0}

# %%
# testing more documents for new nest function
dg_main_test = DataGuidePath()
dg_main_test.insert_document(data7)
dg_main_test.insert_document(data6)
dg_main_test.insert_document(data1)
dg_main_test.insert_document(data2)
dg_main_test.insert_document(data3)
dg_main_test.insert_document(data4)

# %%
print("Main dataguide 'dg_main_test' for reference, not transformed: ")
dg_main_test.print_guide()
# Out:
# Main dataguide 'dg_main_test' for reference, not transformed:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 10, 'arr': 0}
# root.a: {'int': 10, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.b: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 4, 'arr': 0}
# root.b.c: {'int': 1, 'str': 3, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.b.d: {'int': 0, 'str': 3, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.b.e: {'int': 3, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.f: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 3}
# root.f.*: {'int': 7, 'str': 0, 'float': 0, 'date': 0, 'obj': 2, 'arr': 0}
# root.f.*.k: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.f.*.l: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.g: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.common: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 6, 'arr': 0}
# ...

# %%
# Argument 3: Nesting with an empty path list
# Grouping by paths 'a' and 'f', and nesting all other non-grouping attributes under 'other_attrs' as an array
# This also confirms that paths under 'f' (like f.*.k, f.*.l) are retained at the root level
transformed_guide_two_paths_2 = dg_main_test.nest_schema(
    grouping_paths=[Path("a"), Path("f")],
    nest_specs=[("other_attrs", [])]  # Empty list = nest everything except the grouping paths
)
transformed_guide_two_paths_2.print_guide()
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 2, 'arr': 2}
# root.a: {'int': 10, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.f: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 0}
# root.f.*: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.f.*.k: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.f.*.l: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.other_attrs: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 1}
# root.other_attrs.*: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 0}
# root.other_attrs.*.b: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.other_attrs.*.b.c: {'int': 1, 'str': 3, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.other_attrs.*.b.d: {'int': 0, 'str': 3, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.other_attrs.*.b.e: {'int': 3, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# ...

# %%
# Testing one one document, nesting specific fields under a list called details
dg_one_doc.nest_schema(
    nest_specs=[("details", ["b.c", "b.d"])]
).print_guide()
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 1}
# root.details: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 1}
# root.details.*: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 0}
# root.details.*.b: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.details.*.b.c: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.details.*.b.d: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}

# %%
# Test: Nest specific fields into array of objects under "details"
# Fields b.c and b.d are extracted from root and placed inside each element of the "details" array
dg_main_test.nest_schema(
    nest_specs=[("details", ["b.c", "b.d"])]
).print_guide()
# The output is correct because we want to nest only the fields b.c and b.d 
# into a new array called details. Each element in the array is a document containing just those two fields.
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 1}
# root.details: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 1}
# root.details.*: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 0}
# root.details.*.b: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.details.*.b.c: {'int': 1, 'str': 3, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.details.*.b.d: {'int': 0, 'str': 3, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}

# %%
# Testing emp/dept data to now form arguement 2
# First create data below
data8 = {"deptid": 1, "emp": {"name": "Jones", "address": "123 Sesame St."}}
data9 = {"deptid": 1, "emp": {"name": "Smith", "age": 42}}
data10 = {"deptid": 1, "emp": {"name": "Lewis"}, "office": "22A"}

# %%
# Will first display dataguide for reference
prof_dg = DataGuidePath()
prof_dg.insert_document([data8, data9, data10])
print("Printing original professor dataguide:")
prof_dg.print_guide()
# Out:
# Printing original professor dataguide:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 3, 'arr': 0}
# root.deptid: {'int': 3, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.emp: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 3, 'arr': 0}
# root.emp.name: {'int': 0, 'str': 3, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.emp.address: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.emp.age: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.office: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}

# %%
# Test for a group by "deptid", nest by "emps"
prof_dg.nest_schema(
    grouping_paths=["deptid"],
    nest_specs=[("emps", [])]
).print_guide()
# Output is as expected, 'root.emps.*.office: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}'
# is not kept since it is part of emp document
# Aditionally 'deptid' is also kept, and 'root.eps' shows 'arr': 1
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 2, 'arr': 1}
# root.emps: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 1}
# root.emps.*: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 0}
# root.emps.*.emp: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.emps.*.emp.address: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.emps.*.emp.age: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.emps.*.emp.name: {'int': 0, 'str': 3, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.emps.*.office: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.deptid: {'int': 3, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}

# %%
# Test 1: for a group by "deptid", nest by "emps(emp.name, emp.address)"
# Using strings as paths
prof_dg.nest_schema(
    grouping_paths=["deptid"],
    nest_specs=[("emps", ["emp.name", "emp.address"])]
).print_guide() 
# Output is correct, 'root.office: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}' is removed
# since it is not part of nested Paths, and counters are correct
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 2, 'arr': 1}
# root.emps: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 1}
# root.emps.*: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 0}
# root.emps.*.emp: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.emps.*.emp.address: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.emps.*.emp.name: {'int': 0, 'str': 3, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.deptid: {'int': 3, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}

# %%
# Same test as above but with Path objects instead of strings
prof_dg.nest_schema(
    grouping_paths=["deptid"],
    nest_specs=[("emps", [Path("emp.name"), Path("emp.address")])]
).print_guide() 
# Output is identical, works as intended
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 2, 'arr': 1}
# root.emps: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 1}
# root.emps.*: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 0}
# root.emps.*.emp: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.emps.*.emp.address: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.emps.*.emp.name: {'int': 0, 'str': 3, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.deptid: {'int': 3, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}

# %%
# Test 2: Nest everything except the group key
# Group by deptid, nest everything else
prof_dg.nest_schema(
    grouping_paths=["deptid"],
    nest_specs=[("emps", [])]
).print_guide()
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 2, 'arr': 1}
# root.emps: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 1}
# root.emps.*: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 0}
# root.emps.*.emp: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.emps.*.emp.address: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.emps.*.emp.age: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.emps.*.emp.name: {'int': 0, 'str': 3, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.emps.*.office: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.deptid: {'int': 3, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}

# %%
# Test 3: Two parallel arrays with different nested paths
# Nest two sets of fields into separate arrays
# Nesting by ["b.c", "b.d"] and nesting by ["f.k", "g"]
dg_main_test.nest_schema(
    grouping_paths=["a"],
    nest_specs=[
        ("details", ["b.c", "b.d"]),
        ("meta", ["f.k", "g"])
    ]
).print_guide()
# This is correct, only one group a, array details and meta are created, the root correct states 'obj': 3, 'arr': 2
# root.a: {'int': 10} is correct, root.details.*.b.c: 'int': 1, 'str': 3, is also correct because from the orginal
# dataguide we have "root.b.c: {'int': 1, 'str': 3, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}"
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 3, 'arr': 2}
# root.details: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 1}
# root.details.*: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 0}
# root.details.*.b: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.details.*.b.c: {'int': 1, 'str': 3, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.details.*.b.d: {'int': 0, 'str': 3, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.a: {'int': 10, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.meta: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 1}
# root.meta.*: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.meta.*.g: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}

# %%
# Test 4: Nest overlapping but differently scoped paths
# Project b, and nest all other paths (including root-level fields like a, f)
# Slightly different test because path 'b' also appears nested
dg_main_test.nest_schema(
    grouping_paths=["b"],
    nest_specs=[("rest", [])]
).print_guide()
# this is the correct output because 'root.b.c: {'int': 1, 'str': 3, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}' 
# should only have 'int':1, 'str': 3, because there exists another int but it is deeply nested not at root
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 2, 'arr': 1}
# root.rest: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 1}
# root.rest.*: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 1}
# root.rest.*.a: {'int': 10, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.rest.*.common: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 0}
# root.rest.*.common.b: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.rest.*.common.b.c: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.rest.*.common.x: {'int': 4, 'str': 2, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.rest.*.f: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 0}
# root.rest.*.f.*: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.rest.*.f.*.k: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.rest.*.f.*.l: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# ...

# %%
# Nest root-level and nested fields into a single array
# Nest mixed-depth fields into a single array
dg_main_test.nest_schema(
    nest_specs=[("mixed", ["a", "b.c", "f.k"])]
).print_guide()
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 1}
# root.mixed: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 1}
# root.mixed.*: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 0}
# root.mixed.*.a: {'int': 10, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.mixed.*.b: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.mixed.*.b.c: {'int': 1, 'str': 3, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}

# %%
# Creating simple data for testing aggregations now
data11 = [
    {"deptid": 1, "emp": {"age": 42}},
    {"deptid": 2, "emp": {"age": 35}},
    {"deptid": 1, "emp": {"age": 29}},
    {"deptid": 2, "emp": {"age": '31'}},
]
simple_dataguide = DataGuidePath()
simple_dataguide.insert_document(data11)
simple_dataguide.print_guide()
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 4, 'arr': 0}
# root.deptid: {'int': 4, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.emp: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 4, 'arr': 0}
# root.emp.age: {'int': 3, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}

# %%
# Test 1: Testing an avg aggregation by grouping on deptid

simple_dataguide.nest_schema(
    grouping_paths=["deptid"],
    aggregations=[("avg", "emp.age", "avg_age")]
).print_guide()
# Works correctly because there are 3 ints in age, so even one string in the mix output is still as expected
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 2, 'arr': 0}
# root.avg_age: {'int': 0, 'str': 0, 'float': 1, 'date': 0, 'obj': 0, 'arr': 0}
# root.deptid: {'int': 4, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}

# %%
# Test 2: Using similar test as above but on a larger dataset
dg_main_test.nest_schema(
    grouping_paths=["a"],
    aggregations=[("sum", "b.e", "summary.total_e")]
).print_guide()
# Correctly shows root.a 'int': 10, since all 10 docs have path 'a'
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 2, 'arr': 0}
# root.a: {'int': 10, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.summary: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.summary.total_e: {'int': 0, 'str': 0, 'float': 1, 'date': 0, 'obj': 0, 'arr': 0}

# %%
# Another simple dataset to test with but with more complex structure, more deeply nested
two_person_business_data = [
    {
        "deptid": 1,
        "customer": {"id": 101, "name": "Alice"},
        "purchases": [
            {"amount": 200, "category": "electronics"},
            {"amount": 80, "category": "books"}
        ]
    },
    {
        "deptid": 1,
        "customer": {"id": 102, "name": "Bob"},
        "purchases": [
            {"amount": 150, "category": "books"},
            {"amount": "invalid", "category": "groceries"}  # bad data
        ]
    }
]
simple_business_dg = DataGuidePath()
simple_business_dg.insert_document(two_person_business_data)
print("Original 'two_person_business_data' dataguide: ")
simple_business_dg.print_guide()
# Out:
# Original 'two_person_business_data' dataguide:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 2, 'arr': 0}
# root.deptid: {'int': 2, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.customer: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 2, 'arr': 0}
# root.customer.id: {'int': 2, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.customer.name: {'int': 0, 'str': 2, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.purchases: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 2}
# root.purchases.*: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 4, 'arr': 0}
# root.purchases.*.amount: {'int': 3, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.purchases.*.category: {'int': 0, 'str': 4, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}

# %%
# Test Case 1 — Group by deptid, sum valid purchase amounts
simple_business_dg.nest_schema(
    grouping_paths=["deptid"],
    aggregations=[
        ("sum", "purchases.*.amount", "summary.total_spent")
    ]
).print_guide()
# The output is correct, deptid is 2, and total_spent is 1 as float
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 2, 'arr': 0}
# root.summary: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.summary.total_spent: {'int': 0, 'str': 0, 'float': 1, 'date': 0, 'obj': 0, 'arr': 0}
# root.deptid: {'int': 2, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}

# %%
# Test Case 2 — Count purchases per department
simple_business_dg.nest_schema(
    grouping_paths=["deptid"],
    aggregations=[
        ("count", "purchases.*.amount", "summary.num_purchases")
    ]
).print_guide()
# All purchases counted regardless of type, 4 total (2 from Alice, 2 from Bob)
# Output appears correct
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 2, 'arr': 0}
# root.summary: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.summary.num_purchases: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.deptid: {'int': 2, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}

# %%
# Test Case 3 - Multiple aggregations
simple_business_dg.nest_schema(
    grouping_paths=["deptid"],
    aggregations=[
        ("sum", "purchases.*.amount", "summary.total_spent"),
        ("avg", "purchases.*.amount", "summary.avg_spent"),
        ("count", "customer.id", "summary.num_customers")
    ]
).print_guide()
#Output appears correct
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 2, 'arr': 0}
# root.summary: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.summary.avg_spent: {'int': 0, 'str': 0, 'float': 1, 'date': 0, 'obj': 0, 'arr': 0}
# root.summary.num_customers: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.summary.total_spent: {'int': 0, 'str': 0, 'float': 1, 'date': 0, 'obj': 0, 'arr': 0}
# root.deptid: {'int': 2, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}

# %%
# Slightly more complex/ variations in format
# Just two people data for testing
# Creating and printing the dataguide
two_person_business_data2 = [
    {
        "deptid": 1,
        "customer": {"id": 101, "name": "Alice"},
        "purchases": {"amount": 200, "category": "electronics"}
    },
    {
        "deptid": 1,
        "customer": {"id": 102, "name": "Bob"},
        "purchases": [
            {"amount": 150, "category": "books"},
            {"amount": "invalid", "category": "groceries"}  # bad data
        ]
    }
]
simple2_business_dg = DataGuidePath()
simple2_business_dg.insert_document(two_person_business_data2)
print("Original 'two_person_business_data' dataguide: ")
simple2_business_dg.print_guide()
# Out:
# Original 'two_person_business_data' dataguide:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 2, 'arr': 0}
# root.deptid: {'int': 2, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.customer: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 2, 'arr': 0}
# root.customer.id: {'int': 2, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.customer.name: {'int': 0, 'str': 2, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.purchases: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 1}
# root.purchases.amount: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.purchases.category: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.purchases.*: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 2, 'arr': 0}
# root.purchases.*.amount: {'int': 1, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.purchases.*.category: {'int': 0, 'str': 2, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}

# %%
# Test Case 1 — sum on all valid amounts
simple2_business_dg.nest_schema(
    grouping_paths=["deptid"],
    aggregations=[
        ("sum", "purchases.amount", "summary.total_obj"),
        ("sum", "purchases.*.amount", "summary.total_array")
    ]
).print_guide()
# Correctly does two sums, one for the object purchases, and another for the list of purchases.
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 2, 'arr': 0}
# root.summary: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.summary.total_array: {'int': 0, 'str': 0, 'float': 1, 'date': 0, 'obj': 0, 'arr': 0}
# root.summary.total_obj: {'int': 0, 'str': 0, 'float': 1, 'date': 0, 'obj': 0, 'arr': 0}
# root.deptid: {'int': 2, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}

# %%
# Test Case 2 — avg + count of purchases from both formats
simple2_business_dg.nest_schema(
    grouping_paths=["deptid"],
    aggregations=[
        ("avg", "purchases.amount", "summary.avg_obj"),
        ("avg", "purchases.*.amount", "summary.avg_array"),
        ("count", "purchases.amount", "summary.count_obj"),
        ("count", "purchases.*.amount", "summary.count_array")
    ]
).print_guide()
# Output correctly does 1 for each since one document has a list of purchases, and the other document just has one purchase
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 2, 'arr': 0}
# root.summary: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.summary.avg_array: {'int': 0, 'str': 0, 'float': 1, 'date': 0, 'obj': 0, 'arr': 0}
# root.summary.avg_obj: {'int': 0, 'str': 0, 'float': 1, 'date': 0, 'obj': 0, 'arr': 0}
# root.summary.count_array: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.summary.count_obj: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.deptid: {'int': 2, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}

# %%
# Now using more data/documents, but still relatively similar structure for each document

business_data = [
    {
        "deptid": 1,
        "customer": {"id": 101, "name": "Alice"},
        "purchases": [
            {"amount": 200, "category": "electronics"},
            {"amount": 80, "category": "books"}
        ]
    },
    {
        "deptid": 1,
        "customer": {"id": 102, "name": "Bob"},
        "purchases": [
            {"amount": 150, "category": "books"},
            {"amount": "invalid", "category": "groceries"}  # bad data
        ]
    },
    {
        "deptid": 1,
        "customer": {"id": 103, "name": "Charlie"},
        "purchases": [
            {"amount": 300, "category": "electronics"}
        ]
    },
    {
        "deptid": 2,
        "customer": {"id": 104, "name": "Dana"},
        "purchases": [
            {"amount": 50, "category": "groceries"},
            {"amount": 25}  # missing category
        ]
    },
    {
        "deptid": 2,
        "customer": {"id": 105, "name": "Eli"},
        "purchases": [
            {"amount": 100, "category": "books"}
        ]
    },
    {
        "deptid": 2,
        "customer": {"id": 110, "name": "Jack", "email": "jack@example.com"},
        "purchases": [
            {"amount": 90, "category": "books"},
            {"amount": 10, "category": "membership"}
        ]
    },
    {
        "deptid": 3,
        "customer": {"id": 106, "name": "Faye"},
        "purchases": [
            {"amount": 75, "category": "clothing"},
            {"amount": 50, "category": "accessories"}
        ]
    },
    {
        "deptid": 3,
        "customer": {"id": 107, "name": "George"},
        "purchases": [
            {"amount": 125, "category": "electronics"}
        ]
    },
    {
        "deptid": 3,
        "customer": {"id": 108, "name": "Hannah"},
        "purchases": [
            {"amount": 60}
        ]
    },
    {
        "deptid": 1,
        "customer": {"id": 109, "name": "Ivy"},
        "purchases": []  # empty purchase list
    }
]
dg_business_data = DataGuidePath()
dg_business_data.insert_document(business_data)
print("Original simple business data DG:")
dg_business_data.print_guide()
# Out:
# Original simple business data DG:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 10, 'arr': 0}
# root.deptid: {'int': 10, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.customer: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 10, 'arr': 0}
# root.customer.id: {'int': 10, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.customer.name: {'int': 0, 'str': 10, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.customer.email: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.purchases: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 10}
# root.purchases.*: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 14, 'arr': 0}
# root.purchases.*.amount: {'int': 13, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.purchases.*.category: {'int': 0, 'str': 12, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}

# %%
# Test Case 1 — Sum, Avg, Count of Valid Purchase Amounts Per Dept
dg_business_data.nest_schema(
    grouping_paths=["deptid"],
    aggregations=[
        ("sum", "purchases.*.amount", "summary.total_spent"),
        ("avg", "purchases.*.amount", "summary.avg_spent"),
        ("count", "purchases.*.amount", "summary.num_purchases")
    ]
).print_guide()
# Output looks correct with depid at 10 ints, and 3 aggregations showing 1
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 2, 'arr': 0}
# root.summary: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.summary.avg_spent: {'int': 0, 'str': 0, 'float': 1, 'date': 0, 'obj': 0, 'arr': 0}
# root.summary.num_purchases: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.summary.total_spent: {'int': 0, 'str': 0, 'float': 1, 'date': 0, 'obj': 0, 'arr': 0}
# root.deptid: {'int': 10, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}

# %%
# Test Case 2 — Count of Customers

dg_business_data.nest_schema(
    grouping_paths=["deptid"],
    aggregations=[
        ("count", "customer.id", "summary.num_customers")
    ]
).print_guide()
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 2, 'arr': 0}
# root.summary: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.summary.num_customers: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.deptid: {'int': 10, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}

# %%
# Test Case 3 — Invalid Aggregation: Sum on category (string)
dg_business_data.nest_schema(
    grouping_paths=["deptid"],
    aggregations=[
        ("sum", "purchases.*.category", "summary.category_sum")
    ]
).print_guide()
# Logic outputs an error correctly, since sum aggregations cannot be applied to category (stringss)
# Out:
# Skipping aggregation: sum cannot apply to non-numeric purchases.*.category
# No valid aggregation outputs were generated.
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 0}
# root.deptid: {'int': 10, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}

# %%
#  Test Case 4 — Combined Valid and Invalid Aggregations
dg_business_data.nest_schema(
    grouping_paths=["deptid"],
    aggregations=[
        ("sum", "purchases.*.amount", "summary.total_spent"),
        ("avg", "purchases.*.amount", "summary.avg_spent"),
        ("count", "purchases.*.amount", "summary.num_purchases"),
        ("sum", "purchases.*.category", "summary.invalid_sum")  # invalid
    ]
).print_guide()
# Correct output of aggregations that can be performed
# Out:
# Skipping aggregation: sum cannot apply to non-numeric purchases.*.category
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 2, 'arr': 0}
# root.summary: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.summary.avg_spent: {'int': 0, 'str': 0, 'float': 1, 'date': 0, 'obj': 0, 'arr': 0}
# root.summary.num_purchases: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.summary.total_spent: {'int': 0, 'str': 0, 'float': 1, 'date': 0, 'obj': 0, 'arr': 0}
# root.deptid: {'int': 10, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}

# %%
#More complex data for testing
mixed_business_data = [
    # Standard format with purchases as list of objects
    {
        "deptid": 1,
        "customer": {"id": 101, "name": "Alice"},
        "purchases": [
            {"amount": 200, "category": "electronics"},
            {"amount": 80, "category": "books"}
        ]
    },

    # Purchases as a single object, not an array
    {
        "deptid": 1,
        "customer": {"id": 102, "name": "Bob"},
        "purchase": {"amount": 150, "category": "books"}
    },

    # Flattened customer structure + simple purchase amount
    {
        "deptid": 2,
        "customer_id": 103,
        "customer_name": "Charlie",
        "purchase_amount": 300
    },

    # Purchase amount is string → invalid
    {
        "deptid": 2,
        "customer": {"id": 104, "name": "Dana"},
        "purchase": {"amount": "free", "category": "promotion"}
    },

    # Purchases missing category
    {
        "deptid": 2,
        "customer": {"id": 105, "name": "Eli"},
        "purchases": [
            {"amount": 100},
            {"amount": 50, "category": None}
        ]
    },

    # Extra info (email) and valid nested purchases
    {
        "deptid": 3,
        "customer": {"id": 106, "name": "Faye", "email": "faye@example.com"},
        "purchases": [
            {"amount": 75, "category": "clothing"}
        ]
    },

    # Purchases is empty array
    {
        "deptid": 3,
        "customer": {"id": 107, "name": "George"},
        "purchases": []
    },

    # Purchase nested under sales for this source
    {
        "deptid": 3,
        "customer": {"id": 108, "name": "Hannah"},
        "sales": {"amount": 60, "category": "services"},
        "source": "legacy_sales"
    },

    # Completely different layout — event record
    {
        "deptid": 1,
        "event_type": "purchase",
        "user": {"id": 109, "label": "Ivy"},
        "metadata": {"amount": 120, "category": "unknown"}
    },

    # Missing purchase, just customer info
    {
        "deptid": 1,
        "customer": {"id": 110, "name": "Jack"},
        "notes": "no purchase yet"
    }
]

# %%
# Create the DataGuidePath for mixed_business_data
dg_mixed_business = DataGuidePath()
dg_mixed_business.insert_document(mixed_business_data)

print("Original 'mixed_business_data' DataGuide:")
dg_mixed_business.print_guide()
print(f"Total documents: {dg_mixed_business.total_docs}\n")
# Out:
# Original 'mixed_business_data' DataGuide:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 10, 'arr': 0}
# root.deptid: {'int': 10, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.customer: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 8, 'arr': 0}
# root.customer.id: {'int': 8, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.customer.name: {'int': 0, 'str': 8, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.customer.email: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.purchases: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 4}
# root.purchases.*: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 5, 'arr': 0}
# root.purchases.*.amount: {'int': 5, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.purchases.*.category: {'int': 0, 'str': 3, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0, 'NoneType': 1}
# root.purchase: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 2, 'arr': 0}
# ...

# %%
# Test 1: Group by 'deptid'
test1 = dg_mixed_business.nest_schema(
    grouping_paths=["deptid"]
)
print(test1.get_estimate_bounds())
# Output should all 10 total_docs and 0's
# Out:
# {'total_docs': 10, 'max_docs_est impacted': 0, 'min_docs_est impacted': 0}

# %%
print("\n# Test 2: Group by 'deptid' + sum(purchases.*.amount)")
test2 = dg_mixed_business.nest_schema(
    grouping_paths=["deptid"],
    aggregations=[
        ("sum", "purchases.*.amount", "summary.total_array_amount")
    ]
)
print(test2.get_estimate_bounds())
# should be min_docs_est = 5, max_docs_est = 5
# Out:
# # Test 2: Group by 'deptid' + sum(purchases.*.amount)
# {'total_docs': 10, 'max_docs_est impacted': 5, 'min_docs_est impacted': 5}

# %%
print("\n# Test 3: Group by 'deptid' + sum(purchase.amount)")
test3 = dg_mixed_business.nest_schema(
    grouping_paths=["deptid"],
    aggregations=[
        ("sum", "purchase.amount", "summary.total_object_amount")
    ]
)
print(test3.get_estimate_bounds())
# Only 2 docs have purchase.amount
# 1 of them is valid (150), 1 is "free" (invalid)
# Out:
# # Test 3: Group by 'deptid' + sum(purchase.amount)
# {'total_docs': 10, 'max_docs_est impacted': 2, 'min_docs_est impacted': 2}

# %%
print("\n# Test 4: Group by 'deptid' + sum(purchase_amount)")
test4 = dg_mixed_business.nest_schema(
    grouping_paths=["deptid"],
    aggregations=[
        ("sum", "purchase_amount", "summary.total_flat_amount")
    ]
)
print(test4.get_estimate_bounds())
# Only 1 doc has purchase_amount
# Out:
# # Test 4: Group by 'deptid' + sum(purchase_amount)
# {'total_docs': 10, 'max_docs_est impacted': 1, 'min_docs_est impacted': 1}

# %%
print("\n# Test 5: Group by 'deptid' + 3 different aggregations")
test5 = dg_mixed_business.nest_schema(
    grouping_paths=["deptid"],
    aggregations=[
        ("sum", "purchases.*.amount", "summary.total_array_amount"),
        ("sum", "purchase.amount", "summary.total_object_amount"),
        ("sum", "purchase_amount", "summary.total_flat_amount")
    ]
)
print(test5.get_estimate_bounds())
# Only 5 docs for purchases.*.amount, 2 for purchase.amount, 1 for purchase_amount, so 8
# Out:
# # Test 5: Group by 'deptid' + 3 different aggregations
# {'total_docs': 10, 'max_docs_est impacted': 8, 'min_docs_est impacted': 1}

# %%
print("\n# Test 6: Group by 'deptid' + nest customer.id and customer.name")
test6 = dg_mixed_business.nest_schema(
    grouping_paths=["deptid"],
    nest_specs=[
        ("clients", ["customer.id", "customer.name"])
    ]
)
print(test6.get_estimate_bounds())
# NOT WORKING with nest_specs, if keeping need to fix
# Out:
# # Test 6: Group by 'deptid' + nest customer.id and customer.name
# {'total_docs': 10, 'max_docs_est impacted': 0, 'min_docs_est impacted': 0}

# %%
print("\n# Test 7: Group by 'deptid' + nest everything else")
test7 = dg_mixed_business.nest_schema(
    grouping_paths=["deptid"],
    nest_specs=[
        ("everything_else", [])  # nest all other paths
    ]
)
print(test7.get_estimate_bounds())
# NOT WORKING with nest_specs, if keeping need to fix
# Out:
# # Test 7: Group by 'deptid' + nest everything else
# {'total_docs': 10, 'max_docs_est impacted': 0, 'min_docs_est impacted': 0}

# %%
print("\n# Test 8: Group by 'region' (missing field)")
test8 = dg_mixed_business.nest_schema(
    grouping_paths=["region"]
)
print(test8.get_estimate_bounds())
# ALL ZEROS so it works
# Out:
# # Test 8: Group by 'region' (missing field)
# {'total_docs': 10, 'max_docs_est impacted': 0, 'min_docs_est impacted': 0}

# %%
print("\n# Test 9: Group by 'deptid' + sum over metadata.amount (str only)")
test9 = dg_mixed_business.nest_schema(
    grouping_paths=["deptid"],
    aggregations=[
        ("sum", "metadata.amount", "summary.invalid_sum")
    ]
)
print(test9.get_estimate_bounds())
# metadata.amount is a string (120, in one doc)
# Out:
# # Test 9: Group by 'deptid' + sum over metadata.amount (str only)
# {'total_docs': 10, 'max_docs_est impacted': 1, 'min_docs_est impacted': 1}

# %%
# --- For Testing Unnest ---

# %%
simple_data = [
    {
        "order_id": "X1",
        "items": [
            {"name": "Pen", "qty": 2},
            {"name": "Notebook", "qty": 1}
        ]
    }
]

# %%
from DataGuidePathClass import DataGuidePath, Path # Importing needed classes
# Creating simple unnest dataguide
dg_simple_unnest = DataGuidePath()
dg_simple_unnest.insert_document(simple_data)
print("Starting dataguide, not yet transformed")
dg_simple_unnest.print_guide()
# Out:
# Starting dataguide, not yet transformed
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 0}
# root.order_id: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.items: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 1}
# root.items.*: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 2, 'arr': 0}
# root.items.*.name: {'int': 0, 'str': 2, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.items.*.qty: {'int': 2, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}

# %%
# Test 1 Unnest everything under items.*
now_unnested_dg = dg_simple_unnest.unnest_schema([('items.*', [])])
now_unnested_dg.print_guide()
# there are two items, each with 2 names and 2 qty, so this looks valid, also 'items' is gone
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 2, 'arr': 0}
# root.name: {'int': 0, 'str': 2, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.order_id: {'int': 0, 'str': 2, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.qty: {'int': 2, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}

# %%
now_unnested_dg.total_docs
# Currently it says 1 but should be 2 since  we now have
# { "order_id": "X1", "name": "Pen", "qty": 2 } and
# { "order_id": "X1", "name": "Notebook", "qty": 1 }
# Out:
# 2

# %%
#Test 2 field specific for unnesting 
now_unnested_dg2 = dg_simple_unnest.unnest_schema([("items.*", ["qty"])])
now_unnested_dg2.print_guide()
# there are two items, each with 2 names and 2 qty, name does not appear, and qty shows 2, so this appears valid
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 2, 'arr': 0}
# root.order_id: {'int': 0, 'str': 2, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.qty: {'int': 2, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}

# %%
now_unnested_dg2.total_docs
# Out:
# 2

# %%
# Now using more complex data for testing
sales_data = [
    {
        "order_id": "ORD001",
        "customer": {"name": "Alice", "region": "North"},
        "items": [
            {"product": "Pen", "qty": 2, "price": 1.5},
            {"product": "Notebook", "qty": 1, "price": 3.0}
        ]
    },
    {
        "order_id": "ORD002",
        "customer": {"name": "Bob", "region": "South"},
        "items": []
    },
    {
        "order_id": "ORD003",
        "customer": {"name": "Charlie", "region": "East"},
        "items": [
            {"product": "Pencil", "qty": 3, "price": 0.5}
        ]
    }
]

# %%
dg_unnest_testing = DataGuidePath()
dg_unnest_testing.insert_document(sales_data)
print("Original dataguide:")
dg_unnest_testing.print_guide()
# Out:
# Original dataguide:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 3, 'arr': 0}
# root.order_id: {'int': 0, 'str': 3, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.customer: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 3, 'arr': 0}
# root.customer.name: {'int': 0, 'str': 3, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.customer.region: {'int': 0, 'str': 3, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.items: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 3}
# root.items.*: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 3, 'arr': 0}
# root.items.*.product: {'int': 0, 'str': 3, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.items.*.qty: {'int': 3, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.items.*.price: {'int': 0, 'str': 0, 'float': 3, 'date': 0, 'obj': 0, 'arr': 0}

# %%
# Unnest everything under items.*, for 3 documents
now_unnested_dg3 = dg_unnest_testing.unnest_schema([("items.*", [])])
now_unnested_dg3.print_guide()
#every doc has items, and there are a total of 3 products, price and quantity also show 3 so this looks valid
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 4, 'arr': 0}
# root.customer: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 4, 'arr': 0}
# root.customer.name: {'int': 0, 'str': 4, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.customer.region: {'int': 0, 'str': 4, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.order_id: {'int': 0, 'str': 4, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.price: {'int': 0, 'str': 0, 'float': 3, 'date': 0, 'obj': 0, 'arr': 0}
# root.product: {'int': 0, 'str': 3, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.qty: {'int': 3, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}

# %%
now_unnested_dg3.total_docs
# Out:
# 4

# %%
# Only extract qty and price from each item
now_unnested_dg4 = dg_unnest_testing.unnest_schema([("items.*", ["qty", "price"])])
now_unnested_dg4.print_guide()
# like last test this looks valid since we have 3 of each and product does not appear since not in filter
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 4, 'arr': 0}
# root.customer: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 4, 'arr': 0}
# root.customer.name: {'int': 0, 'str': 4, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.customer.region: {'int': 0, 'str': 4, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.order_id: {'int': 0, 'str': 4, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.price: {'int': 0, 'str': 0, 'float': 3, 'date': 0, 'obj': 0, 'arr': 0}
# root.qty: {'int': 3, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}

# %%
# What if discounted.value only exists once
now_unnested_dg5 = dg_unnest_testing.unnest_schema([("items.*", ["discount.value"])])
now_unnested_dg5.print_guide()
# customer.name and customer.region information is expected, 
# root.items.discount.value: {'int': 0, 'str': 0, 'float': 1, 'date': 0, 'obj': 0, 'arr': 0} is correct,
# overall looks correct
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 4, 'arr': 0}
# root.customer: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 4, 'arr': 0}
# root.customer.name: {'int': 0, 'str': 4, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.customer.region: {'int': 0, 'str': 4, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.order_id: {'int': 0, 'str': 4, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}

# %%
# Now using more complex data for testing
sales_data = [
    {
        "order_id": "ORD001",
        "customer": {"name": "Alice", "region": "North"},
        "items": [
            {"product": "Pen", "qty": 2, "price": 1.5},
            {"product": "Notebook", "qty": 1, "price": 3.0}
        ]
    },
    {
        "order_id": "ORD002",
        "customer": {"name": "Bob", "region": "South"},
        "items": []
    },
    {
        "order_id": "ORD003",
        "customer": {"name": "Charlie", "region": "East"},
        "items": [
            {"product": "Pencil", "qty": 3, "price": 0.5}
        ]
    },
    {
        "order_id": "ORD004",
        "items": [
            {"product": "Eraser", "qty": 2},
            {"product": "Ruler", "qty": 1, "price": 2.0}
        ]
    },
    {
        "order_id": "ORD005",
        "customer": {"name": "Dana"},
        "items": [
            {"product": "Pen", "qty": 1, "price": 1.5, "discount": {"type": "student", "value": 0.5}},
            {"product": "Notebook", "qty": 2, "price": 3.0}
        ]
    },
    {
        "order_id": "ORD006",
        "customer": {"name": "Eve", "region": "West"},
        "items": [
            {"product": "Marker", "qty": 2}
        ]
    },
    {
        "order_id": "ORD007",
        "items": None
    }
]

# %%
larger_dg = DataGuidePath()
larger_dg.insert_document(sales_data)
print("Original larger dataguide:")
larger_dg.print_guide()
# Out:
# Original larger dataguide:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 7, 'arr': 0}
# root.order_id: {'int': 0, 'str': 7, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.customer: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 5, 'arr': 0}
# root.customer.name: {'int': 0, 'str': 5, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.customer.region: {'int': 0, 'str': 4, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.items: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 6, 'NoneType': 1}
# root.items.*: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 8, 'arr': 0}
# root.items.*.product: {'int': 0, 'str': 8, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.items.*.qty: {'int': 8, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.items.*.price: {'int': 0, 'str': 0, 'float': 6, 'date': 0, 'obj': 0, 'arr': 0}
# root.items.*.discount: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 0}
# ...

# %%
# Unnest everything under items.*, for 7 documents
larger_dg_unnested = larger_dg.unnest_schema([("items.*", [])])
larger_dg_unnested.print_guide()
# expected output is 10docs total
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 10, 'arr': 0}
# root.customer: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 7, 'arr': 0}
# root.customer.name: {'int': 0, 'str': 7, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.customer.region: {'int': 0, 'str': 6, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.discount: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.discount.type: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.discount.value: {'int': 0, 'str': 0, 'float': 1, 'date': 0, 'obj': 0, 'arr': 0}
# root.order_id: {'int': 0, 'str': 10, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.price: {'int': 0, 'str': 0, 'float': 6, 'date': 0, 'obj': 0, 'arr': 0}
# root.product: {'int': 0, 'str': 8, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.qty: {'int': 8, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}

# %%
# More testing coming soon

# %%
# Testing Union and Cartesian product

# %%
cp_doc = {'a': 1, 'b': {'c': 99}}
cp_doc2 = {'b': {'c': 99}, 'd':'two'}

# %%
#Testing Union simpler docs
dg_2 = DataGuidePath()
union_dg1 = DataGuidePath()
union_dg1.insert_document([cp_doc, cp_doc2])
print("Data guide with two documents")
union_dg1.print_guide()
# Out:
# Data guide with two documents
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 2, 'arr': 0}
# root.a: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.b: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 2, 'arr': 0}
# root.b.c: {'int': 2, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.d: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}

# %%
# now to union two dataguides if the result is the same as inserting the docs into one guide
first_dg = DataGuidePath()
first_dg.insert_document(cp_doc)
second_dg = DataGuidePath()
second_dg.insert_document(cp_doc2)
union_dg = DataGuidePath()
union_dg = first_dg.union(second_dg)
print("Testing the union dg:")
union_dg.print_guide()
# Out:
# Testing the union dg:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 2, 'arr': 0}
# root.a: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.b: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 2, 'arr': 0}
# root.b.c: {'int': 2, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.d: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}

# %%
#Testing Union larger docs
two_docs_guide = DataGuidePath()
two_docs_guide.insert_document([data1, data2])
print("Data guide with two documents")
two_docs_guide.print_guide()
# Out:
# Data guide with two documents
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 2, 'arr': 0}
# root.a: {'int': 2, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.b: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 2, 'arr': 0}
# root.b.c: {'int': 1, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.b.d: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.b.e: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.f: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 1}
# root.f.*: {'int': 3, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.g: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}

# %%
# now to union two dataguides if the result is the same as inserting the docs into one guide
first_dg = DataGuidePath()
first_dg.insert_document(data1)
second_dg = DataGuidePath()
second_dg.insert_document(data2)
union_dg = DataGuidePath()
union_dg = first_dg.union(second_dg)
print("Testing the union dg:")
union_dg.print_guide()
# the output is the same, working as expected, the guides are identical
# Out:
# Testing the union dg:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 2, 'arr': 0}
# root.g: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.a: {'int': 2, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.b: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 2, 'arr': 0}
# root.b.c: {'int': 1, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.b.d: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.b.e: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.f: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 1}
# root.f.*: {'int': 3, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}

# %%
# Testing to see if the counters update correctly
# will use the same document, for two different guides
two_same_docs_guide = DataGuidePath()
two_same_docs_guide.insert_document([data1, data1])
print("Data guide with two documents")
two_same_docs_guide.print_guide()
# Out:
# Data guide with two documents
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 2, 'arr': 0}
# root.a: {'int': 2, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.b: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 2, 'arr': 0}
# root.b.c: {'int': 2, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.b.d: {'int': 0, 'str': 2, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.b.e: {'int': 2, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.f: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 2}
# root.f.*: {'int': 6, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}

# %%
# testing to make sure counters get added correctly
first_dg_samedoc = DataGuidePath()
first_dg_samedoc.insert_document(data1)
second_dg_samedoc = DataGuidePath()
second_dg_samedoc.insert_document(data1)
union_dg_samedoc = DataGuidePath()
union_dg_samedoc = first_dg_samedoc.union(second_dg_samedoc)
print("Testing the union dg counters:")
union_dg_samedoc.print_guide()
# The counters are correctly doubled, and all paths match, so the dataguide union works as intended
# Out:
# Testing the union dg counters:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 2, 'arr': 0}
# root.a: {'int': 2, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.b: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 2, 'arr': 0}
# root.b.d: {'int': 0, 'str': 2, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.b.c: {'int': 2, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.b.e: {'int': 2, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.f: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 2}
# root.f.*: {'int': 6, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}

# %%
null_doc= {
        "order_id": "ORD007",
        "items": None
    }

# %%
#Testing to see if nulls are also unioned correctly, edge case
two_same_docs_guide = DataGuidePath()
two_same_docs_guide.insert_document([null_doc, null_doc])
print("Data guide with two documents")
two_same_docs_guide.print_guide()
# Out:
# Data guide with two documents
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 2, 'arr': 0}
# root.order_id: {'int': 0, 'str': 2, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.items: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0, 'NoneType': 2}

# %%
first_dg_samedoc_null = DataGuidePath()
first_dg_samedoc_null.insert_document(null_doc)
second_dg_samedoc_null = DataGuidePath()
second_dg_samedoc_null.insert_document(null_doc)
union_dg_samedoc_null = DataGuidePath()
union_dg_samedoc_null = first_dg_samedoc_null.union(second_dg_samedoc_null)
print("Testing the union dg counters for null:")
union_dg_samedoc_null.print_guide()
# null counter also works as intended for union
# Out:
# Testing the union dg counters for null:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 2, 'arr': 0}
# root.items: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0, 'NoneType': 2}
# root.order_id: {'int': 0, 'str': 2, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}

# %%
# Now will test on larger sample fo 7 docs 
full_guide = DataGuidePath()
full_guide.insert_document([data1, data2, data3, data4, data5, data6, data7])
full_guide.print_guide()
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 11, 'arr': 0}
# root.a: {'int': 11, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.b: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 5, 'arr': 0}
# root.b.c: {'int': 1, 'str': 3, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.b.d: {'int': 0, 'str': 3, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.b.e: {'int': 4, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.f: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 4}
# root.f.*: {'int': 7, 'str': 0, 'float': 0, 'date': 0, 'obj': 3, 'arr': 0}
# root.f.*.l: {'int': 2, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.f.*.k: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.g: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.common: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 6, 'arr': 0}
# root.common.x: {'int': 4, 'str': 2, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# ...

# %%
union_dg_test_1 = DataGuidePath()
union_dg_test_1.insert_document([data1, data2, data3])
union_dg_test_2 = DataGuidePath()
union_dg_test_2.insert_document([data4, data5, data6, data7])
union_dg_res = DataGuidePath()
union_dg_res = union_dg_test_1.union(union_dg_test_2)
print("Testing the union dg on 7 docs:")
union_dg_res.print_guide()
# The two dataguides look identical in paths and counters, working as intended
# Out:
# Testing the union dg on 7 docs:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 11, 'arr': 0}
# root.g: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.u2: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.common: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 6, 'arr': 0}
# root.common.x: {'int': 4, 'str': 2, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.common.b: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 0}
# root.common.b.c: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.a: {'int': 11, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.u1: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.v2: {'int': 0, 'str': 0, 'float': 1, 'date': 0, 'obj': 0, 'arr': 0}
# root.v1: {'int': 0, 'str': 0, 'float': 1, 'date': 0, 'obj': 0, 'arr': 0}
# root.b: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 5, 'arr': 0}
# ...

# %%
union_dg_res.total_Docs
# Out:
# 11

# %%
# Testing Cartesian product from here

# %%
# test data for simple cartesian testing
cp_doc = {'a': 1, 'b': {'c': 99}}
cp_doc2 = {'d': {'e': 99}, 'f':'two'}
# later need to test what to do in the case we have matching keys, example 'a': 1 in one doc and 'a' : 'str' in the other
# in such cases one must be renamed, for example  'a': 1 and 'a2' : 'str' , so that the keys are unique

# %%
# CP of the two datassets above would be:

# {'a': 1, 'b': {'c': 99}, 'd': {'e': 99}, 'f':'two'}

# %%
# a cartesian product of two different docs should also be 1x1
cp_dg_1 = DataGuidePath()
cp_dg_1.insert_document([cp_doc])
cp_dg_2 = DataGuidePath()
cp_dg_2.insert_document([cp_doc2])
cp_dg_res = DataGuidePath()
cp_dg_res = cp_dg_1.cartesian_product(cp_dg_2)
print("Cartersian product of 2 docs")
cp_dg_res.print_guide()
# Out:
# Cartersian product of 2 docs
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 0}
# root.a: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.b: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 0}
# root.b.c: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.d: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 0}
# root.d.e: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.f: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}

# %%
# Now testing cartesian dg of a 2 x 3
cp_dg_1 = DataGuidePath()
cp_dg_1.insert_document([cp_doc, cp_doc])
cp_dg_2 = DataGuidePath()
cp_dg_2.insert_document([cp_doc2, cp_doc2, cp_doc2])
cp_dg_res = DataGuidePath()
cp_dg_res = cp_dg_1.cartesian_product(cp_dg_2)
print("Cartersian product of 2 x 3 docs")
cp_dg_res.print_guide()
# Out:
# Cartersian product of 2 x 3 docs
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 6, 'arr': 0}
# root.a: {'int': 6, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.b: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 6, 'arr': 0}
# root.b.c: {'int': 6, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.d: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 6, 'arr': 0}
# root.d.e: {'int': 6, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.f: {'int': 0, 'str': 6, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}

# %%
# Testing CP of two dataguides with the same document to test renaming
cp_dg_1 = DataGuidePath()
cp_dg_1.insert_document([cp_doc])
cp_dg_2 = DataGuidePath()
cp_dg_2.insert_document([cp_doc])
cp_dg_res = DataGuidePath()
cp_dg_res = cp_dg_1.cartesian_product(cp_dg_2)
print("Cartesian product of 2 docs")
cp_dg_res.print_guide()

# all the counters should be 1's still
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[116], line 7
#       5 cp_dg_2.insert_document([cp_doc])
#       6 cp_dg_res = DataGuidePath()
# ----> 7 cp_dg_res = cp_dg_1.cartesian_product(cp_dg_2)
#       8 print("Cartesian product of 2 docs")
#       9 cp_dg_res.print_guide()
#
# File c:\Users\ggala\Documents\DataGuideOperations\TrieDataGuide\DataGuidePathClass.py:1041, in DataGuidePath.cartesian_product(self, other, rename_conflicts, rename_prefix)
#    1038         msg_lines.append(f"  ... and {more} more (showing first 10).")
#    1040     msg_lines.append("\nTo resolve this and rename path(s), set rename_conflicts=True.")
# -> 1041     raise ValueError("\n".join(msg_lines))
#    1043 # If renaming requested, create a renamed copy of other
#    1044 other_for_cp = other
#
# ValueError: Conflicting top-level keys detected (2):
#   - a
#   - b
#
# ...

# %%
# Printing the original dg:
cp_dg_1.print_guide()
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 0}
# root.a: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.b: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 0}
# root.b.c: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}

# %%
# Try rename and the CP
cp_dg_1 = cp_dg_1.rename('a', 'f').rename('b', 'g')
# Out:
# Renamed 1 path(s).
#   a -> f
# Renamed 2 path(s).
#   b -> g
#   b.c -> g.c

# %%
# Checking to see what happens to counters in DG with renamed Paths
cp_dg_1.print_guide()
# Counters are all 1's correct
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 0}
# root.f: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.g: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 0}
# root.g.c: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}

# %%
# Now calling CP and printing the data guide where rename has been used
cp_dg_res = cp_dg_1.cartesian_product(cp_dg_2)
cp_dg_res.print_guide()
# Correctly performs CP since no matching paths
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 0}
# root.a: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.g: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 0}
# root.g.c: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.b: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 0}
# root.b.c: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.f: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}

# %%
# Trying to rename a path to an existing key, it should not work
# Since we have path g, try renaming a -> g

cp_dg_res = cp_dg_res.rename('a', 'g')
# error is correct
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[121], line 4
#       1 # Trying to rename a path to an existing key, it should not work
#       2 # Since we have path g, try renaming a -> g
# ----> 4 cp_dg_res = cp_dg_res.rename('a', 'g')
#
# File c:\Users\ggala\Documents\DataGuideOperations\TrieDataGuide\DataGuidePathClass.py:863, in DataGuidePath.rename(self, old_path, new_path, inplace)
#     860     raise TypeError("new_path must be a string or Path")
#     862 if self.search(str(new_p)) and old_p != new_p:
# --> 863     raise ValueError(f"Rename would cause a collision: '{str(new_p)}' already exists in the guide.")
#     865 # Gather all paths (leaf and intermediate) from the guide
#     866 all_paths = set()
#
# ValueError: Rename would cause a collision: 'g' already exists in the guide.

# %%
# DG should remain unchanged
cp_dg_res.print_guide()
# We can see path 'a' still exist with correct counter
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 0}
# root.a: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.g: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 0}
# root.g.c: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.b: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 0}
# root.b.c: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.f: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}

# %%
# Testing CP of two dataguides with the same document to test renaming with a name passed
cp_dg_1 = DataGuidePath()
cp_dg_1.insert_document([cp_doc])
cp_dg_2 = DataGuidePath()
cp_dg_2.insert_document([cp_doc])
cp_dg_res = DataGuidePath()
cp_dg_res = cp_dg_1.cartesian_product(cp_dg_2, rename_prefix="test", rename_conflicts=True)
print("Cartersian product of 2 docs")
cp_dg_res.print_guide()
# conflicting paths is changed with test inserted since rename_conflicts is True
# Out:
# Auto-renamed conflicting top-level keys:
#   - a -> atest1
#   - b -> btest1
# Cartersian product of 2 docs
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 0}
# root.a: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.atest1: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.b: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 0}
# root.b.c: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.btest1: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.btest1.c: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}

# %%
# Testing the same as above but what if rename_conflicts=False
cp_dg_1 = DataGuidePath()
cp_dg_1.insert_document([cp_doc])
cp_dg_2 = DataGuidePath()
cp_dg_2.insert_document([cp_doc])
cp_dg_res = DataGuidePath()
cp_dg_res = cp_dg_1.cartesian_product(cp_dg_2, rename_prefix="test", rename_conflicts=False)
print("Cartersian product of 2 docs")
cp_dg_res.print_guide()
# Error is correct as expected
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[124], line 7
#       5 cp_dg_2.insert_document([cp_doc])
#       6 cp_dg_res = DataGuidePath()
# ----> 7 cp_dg_res = cp_dg_1.cartesian_product(cp_dg_2, rename_prefix="test", rename_conflicts=False)
#       8 print("Cartersian product of 2 docs")
#       9 cp_dg_res.print_guide()
#
# File c:\Users\ggala\Documents\DataGuideOperations\TrieDataGuide\DataGuidePathClass.py:1041, in DataGuidePath.cartesian_product(self, other, rename_conflicts, rename_prefix)
#    1038         msg_lines.append(f"  ... and {more} more (showing first 10).")
#    1040     msg_lines.append("\nTo resolve this and rename path(s), set rename_conflicts=True.")
# -> 1041     raise ValueError("\n".join(msg_lines))
#    1043 # If renaming requested, create a renamed copy of other
#    1044 other_for_cp = other
#
# ...

# %%
# Testing the same as above but what if parameter rename_conflicts is absent
cp_dg_1 = DataGuidePath()
cp_dg_1.insert_document([cp_doc])
cp_dg_2 = DataGuidePath()
cp_dg_2.insert_document([cp_doc])
cp_dg_res = DataGuidePath()
cp_dg_res = cp_dg_1.cartesian_product(cp_dg_2, rename_prefix="test")
print("Cartersian product of 2 docs")
cp_dg_res.print_guide()
# Error is correct as expected
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[125], line 7
#       5 cp_dg_2.insert_document([cp_doc])
#       6 cp_dg_res = DataGuidePath()
# ----> 7 cp_dg_res = cp_dg_1.cartesian_product(cp_dg_2, rename_prefix="test")
#       8 print("Cartersian product of 2 docs")
#       9 cp_dg_res.print_guide()
#
# File c:\Users\ggala\Documents\DataGuideOperations\TrieDataGuide\DataGuidePathClass.py:1041, in DataGuidePath.cartesian_product(self, other, rename_conflicts, rename_prefix)
#    1038         msg_lines.append(f"  ... and {more} more (showing first 10).")
#    1040     msg_lines.append("\nTo resolve this and rename path(s), set rename_conflicts=True.")
# -> 1041     raise ValueError("\n".join(msg_lines))
#    1043 # If renaming requested, create a renamed copy of other
#    1044 other_for_cp = other
#
# ValueError: Conflicting top-level keys detected (2):
#   - a
# ...

# %%
# testing with more docs
cp_dg_test_1 = DataGuidePath()
cp_dg_test_1.insert_document([data1, data2, data3])
cp_dg_test_2 = DataGuidePath()
cp_dg_test_2.insert_document([data4, data5, data6, data7])

# business_data has 10 more documents of different data, combining for testing
cp_dg_test_3 = DataGuidePath()
cp_dg_test_3.insert_document(business_data)
cp_dg_res_large = DataGuidePath()
# 5 docs in first data guide and 10 docs in second DG
cp_dg_res_large = cp_dg_test_1.cartesian_product(cp_dg_test_3)

# %%
# should have 50 total docs
cp_dg_res_large.total_docs
# Out:
# 50

# %%
cp_dg_res_large.print_guide()
# Dataguide should show 50 objects at root, looks correct
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 50, 'arr': 0}
# root.g: {'int': 10, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.u2: {'int': 0, 'str': 10, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.deptid: {'int': 50, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.common: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 30, 'arr': 0}
# root.common.x: {'int': 20, 'str': 10, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.common.b: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 10, 'arr': 0}
# root.common.b.c: {'int': 10, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.a: {'int': 50, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.u1: {'int': 0, 'str': 10, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.customer: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 50, 'arr': 0}
# root.customer.id: {'int': 50, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# ...

# %%
cp_dg_res_large.total_docs
# 50 total docs, checking total is correct

# %%
unpacking = DataGuidePath()
unpacking.insert_document([data1, data2, data3])
unpacking.total_docs
# 5 total docs, short test to make sure lists are being inserted properly
# Out:
# 5

# %%
# confirming object counters are correct
unpacking.print_guide()

# %%
# confirming document entry works multiple ways
unpacking2 = DataGuidePath()
unpacking2.insert_document([data1, data2] +data3)
unpacking2.total_docs
# Out:
# 5

# %%
# confirming objects and counters are correct
unpacking2.print_guide()
# correctly shows 5 objects at root
# Out:
# root: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 5, 'arr': 0}
# root.a: {'int': 5, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.b: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 2, 'arr': 0}
# root.b.c: {'int': 1, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.b.d: {'int': 0, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.b.e: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.f: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 1}
# root.f.*: {'int': 3, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.g: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.common: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 3, 'arr': 0}
# root.common.x: {'int': 2, 'str': 1, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# root.common.b: {'int': 0, 'str': 0, 'float': 0, 'date': 0, 'obj': 1, 'arr': 0}
# root.common.b.c: {'int': 1, 'str': 0, 'float': 0, 'date': 0, 'obj': 0, 'arr': 0}
# ...
